# %% [markdown]
# <a href="https://colab.research.google.com/github/nickthelegend/stable-diffusion-colab/blob/main/Copy_of_kohya_LoRA_dreambooth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![visitors](https://visitor-badge.glitch.me/badge?page_id=linaqruf.lora-dreambooth) [![](https://dcbadge.vercel.app/api/shield/850007095775723532?style=flat)](https://lookup.guru/850007095775723532) [![ko-fi](https://img.shields.io/badge/Support%20me%20on%20Ko--fi-F16061?logo=ko-fi&logoColor=white&style=flat)](https://ko-fi.com/linaqruf) <a href="https://saweria.co/linaqruf"><img alt="Saweria" src="https://img.shields.io/badge/Saweria-7B3F00?style=flat&logo=ko-fi&logoColor=white"/></a>
#
# # **Kohya LoRA Dreambooth**
# A Colab Notebook For LoRA Training (Dreambooth Method)

# %% [markdown]
# | Notebook Name | Description | Link | V14 |
# | --- | --- | --- | --- |
# | [Kohya LoRA Dreambooth](https://github.com/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) | LoRA Training (Dreambooth method) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) | [![](https://img.shields.io/static/v1?message=Older%20Version&logo=googlecolab&labelColor=5c5c5c&color=e74c3c&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/ff701379c65380c967cd956e4e9e8f6349563878/kohya-LoRA-dreambooth.ipynb) |
# | [Kohya LoRA Fine-Tuning](https://github.com/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb) | LoRA Training (Fine-tune method) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb) | [![](https://img.shields.io/static/v1?message=Older%20Version&logo=googlecolab&labelColor=5c5c5c&color=e74c3c&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/ff701379c65380c967cd956e4e9e8f6349563878/kohya-LoRA-finetuner.ipynb) |
# | [Kohya Trainer](https://github.com/Linaqruf/kohya-trainer/blob/main/kohya-trainer.ipynb) | Native Training | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-trainer.ipynb) | [![](https://img.shields.io/static/v1?message=Older%20Version&logo=googlecolab&labelColor=5c5c5c&color=e74c3c&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/ff701379c65380c967cd956e4e9e8f6349563878/kohya-trainer.ipynb) |
# | [Kohya Dreambooth](https://github.com/Linaqruf/kohya-trainer/blob/main/kohya-dreambooth.ipynb) | Dreambooth Training | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-dreambooth.ipynb) | [![](https://img.shields.io/static/v1?message=Older%20Version&logo=googlecolab&labelColor=5c5c5c&color=e74c3c&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/ff701379c65380c967cd956e4e9e8f6349563878/kohya-dreambooth.ipynb) |
# | [Cagliostro Colab UI](https://github.com/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb) `NEW`| A Customizable Stable Diffusion Web UI| [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb) |

# %% [markdown]
# # I. Install Kohya Trainer

# %%
# @title ## 1.1. Install Dependencies
# @markdown Clone Kohya Trainer from GitHub and check for updates. Use textbox below if you want to checkout other branch or old commit. Leave it empty to stay the HEAD on main.  This will also install the required libraries.
import os
import zipfile
import shutil
import time
from subprocess import getoutput
from IPython.utils import capture
from google.colab import drive

# %store -r

# root_dir
root_dir = "/content"
deps_dir = os.path.join(root_dir, "deps")
repo_dir = os.path.join(root_dir, "kohya-trainer")
training_dir = os.path.join(root_dir, "LoRA")
pretrained_model = os.path.join(root_dir, "pretrained_model")
vae_dir = os.path.join(root_dir, "vae")
config_dir = os.path.join(training_dir, "config")

# repo_dir
accelerate_config = os.path.join(repo_dir, "accelerate_config/config.yaml")
tools_dir = os.path.join(repo_dir, "tools")
finetune_dir = os.path.join(repo_dir, "finetune")

for store in [
    "root_dir",
    "deps_dir",
    "repo_dir",
    "training_dir",
    "pretrained_model",
    "vae_dir",
    "accelerate_config",
    "tools_dir",
    "finetune_dir",
    "config_dir",
]:
    with capture.capture_output() as cap:
        # %store {store}
        del cap

repo_url = "https://github.com/Linaqruf/kohya-trainer"
bitsandytes_main_py = "/usr/local/lib/python3.10/dist-packages/bitsandbytes/cuda_setup/main.py"
branch = ""  # @param {type: "string"}
install_xformers = True  # @param {'type':'boolean'}
mount_drive = True  # @param {type: "boolean"}
verbose = False # @param {type: "boolean"}

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents


def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)


def clone_repo(url):
    if not os.path.exists(repo_dir):
        os.chdir(root_dir)
        # !git clone {url} {repo_dir}
    else:
        os.chdir(repo_dir)
        # !git pull origin {branch} if branch else !git pull


def ubuntu_deps(url, name, dst):
    # !wget {'-q' if not verbose else ''} --show-progress {url}
    with zipfile.ZipFile(name, "r") as deps:
        deps.extractall(dst)
    # !dpkg -i {dst}/*
    os.remove(name)
    shutil.rmtree(dst)


def install_dependencies():
    s = getoutput('nvidia-smi')

    if 'T4' in s:
        # !sed -i "s@cpu@cuda@" library/model_util.py

    # !pip install {'-q' if not verbose else ''} --upgrade -r requirements.txt
    # !pip install {'-q' if not verbose else ''} torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U

    if install_xformers:
        # !pip install {'-q' if not verbose else ''} xformers==0.0.19 triton==2.0.0 -U

    from accelerate.utils import write_basic_config

    if not os.path.exists(accelerate_config):
        write_basic_config(save_location=accelerate_config)


def remove_bitsandbytes_message(filename):
    welcome_message = """
def evaluate_cuda_setup():
    print('')
    print('='*35 + 'BUG REPORT' + '='*35)
    print('Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues')
    print('For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link')
    print('='*80)"""

    new_welcome_message = """
def evaluate_cuda_setup():
    import os
    if 'BITSANDBYTES_NOWELCOME' not in os.environ or str(os.environ['BITSANDBYTES_NOWELCOME']) == '0':
        print('')
        print('=' * 35 + 'BUG REPORT' + '=' * 35)
        print('Welcome to bitsandbytes. For bug reports, please submit your error trace to: https://github.com/TimDettmers/bitsandbytes/issues')
        print('For effortless bug reporting copy-paste your error into this form: https://docs.google.com/forms/d/e/1FAIpQLScPB8emS3Thkp66nvqwmjTEgxp8Y9ufuWTzFyr9kJ5AoI47dQ/viewform?usp=sf_link')
        print('To hide this message, set the BITSANDBYTES_NOWELCOME variable like so: export BITSANDBYTES_NOWELCOME=1')
        print('=' * 80)"""

    contents = read_file(filename)
    new_contents = contents.replace(welcome_message, new_welcome_message)
    write_file(filename, new_contents)


def main():
    os.chdir(root_dir)

    if mount_drive:
        if not os.path.exists("/content/drive"):
            drive.mount("/content/drive")

    for dir in [
        deps_dir,
        training_dir,
        config_dir,
        pretrained_model,
        vae_dir
    ]:
        os.makedirs(dir, exist_ok=True)

    clone_repo(repo_url)

    if branch:
        os.chdir(repo_dir)
        status = os.system(f"git checkout {branch}")
        if status != 0:
            raise Exception("Failed to checkout branch or commit")

    os.chdir(repo_dir)

    # !apt -y update {'-qq' if not verbose else ''}
    # !apt install libunwind8-dev {'-qq' if not verbose else ''}

    ubuntu_deps(
        "https://huggingface.co/Linaqruf/fast-repo/resolve/main/deb-libs.zip",
        "deb-libs.zip",
        deps_dir,
    )

    install_dependencies()
    time.sleep(3)

    remove_bitsandbytes_message(bitsandytes_main_py)

    os.environ["LD_PRELOAD"] = "libtcmalloc.so"
    os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
    os.environ["BITSANDBYTES_NOWELCOME"] = "1"
    os.environ["SAFETENSORS_FAST_GPU"] = "1"

    cuda_path = "/usr/local/cuda-11.8/targets/x86_64-linux/lib/"
    ld_library_path = os.environ.get("LD_LIBRARY_PATH", "")
    os.environ["LD_LIBRARY_PATH"] = f"{ld_library_path}:{cuda_path}"

main()
# Out:
# Mounted at /content/drive
# Cloning into '/content/kohya-trainer'...
# remote: Enumerating objects: 2231, done.
# remote: Counting objects: 100% (897/897), done.
# remote: Compressing objects: 100% (244/244), done.
# remote: Total 2231 (delta 703), reused 763 (delta 653), pack-reused 1334
# Receiving objects: 100% (2231/2231), 3.87 MiB | 14.29 MiB/s, done.
# Resolving deltas: 100% (1460/1460), done.
# 16 packages can be upgraded. Run 'apt list --upgradable' to see them.
# The following NEW packages will be installed:
#   libunwind-dev
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 472 kB of archives.
# After this operation, 4,164 kB of additional disk space will be used.
# Selecting previously unselected package libunwind-dev:amd64.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../libunwind-dev_1.2.1-9ubuntu0.1_amd64.deb ...
# Unpacking libunwind-dev:amd64 (1.2.1-9ubuntu0.1) ...
# Setting up libunwind-dev:amd64 (1.2.1-9ubuntu0.1) ...
# Processing triggers for man-db (2.9.1-1) ...
# deb-libs.zip        100%[===================>]   2.23M  --.-KB/s    in 0.04s
# Selecting previously unselected package aria2.
# (Reading database ... 123122 files and directories currently installed.)
# Preparing to unpack .../aria2_1.35.0-1build1_amd64.deb ...
# Unpacking aria2 (1.35.0-1build1) ...
# dpkg: warning: downgrading google-perftools from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack .../google-perftools_2.5-2.2ubuntu3_all.deb ...
# Unpacking google-perftools (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.35.0-1build1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.35.0-1build1) ...
# Selecting previously unselected package libc-ares2:amd64.
# Preparing to unpack .../libc-ares2_1.15.0-1ubuntu0.1_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# dpkg: warning: downgrading libgoogle-perftools4:amd64 from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack .../libgoogle-perftools4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools4 (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Selecting previously unselected package libgoogle-perftools-dev.
# Preparing to unpack .../libgoogle-perftools-dev_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Selecting previously unselected package liblz4-tool.
# Preparing to unpack .../liblz4-tool_1.9.2-2ubuntu0.20.04.1_all.deb ...
# Unpacking liblz4-tool (1.9.2-2ubuntu0.20.04.1) ...
# dpkg: warning: downgrading libtcmalloc-minimal4:amd64 from 2.7-1ubuntu2 to 2.5-2.2ubuntu3
# Preparing to unpack .../libtcmalloc-minimal4_2.5-2.2ubuntu3_amd64.deb ...
# Unpacking libtcmalloc-minimal4 (2.5-2.2ubuntu3) over (2.7-1ubuntu2) ...
# Selecting previously unselected package lz4.
# Preparing to unpack .../lz4_1.9.2-2ubuntu0.20.04.1_amd64.deb ...
# Unpacking lz4 (1.9.2-2ubuntu0.20.04.1) ...
# Setting up libc-ares2:amd64 (1.15.0-1ubuntu0.1) ...
# Setting up libtcmalloc-minimal4 (2.5-2.2ubuntu3) ...
# Setting up lz4 (1.9.2-2ubuntu0.20.04.1) ...
# Setting up libaria2-0:amd64 (1.35.0-1build1) ...
# Setting up libgoogle-perftools4 (2.5-2.2ubuntu3) ...
# Setting up libgoogle-perftools-dev (2.5-2.2ubuntu3) ...
# Setting up liblz4-tool (1.9.2-2ubuntu0.20.04.1) ...
# Setting up aria2 (1.35.0-1build1) ...
# Setting up google-perftools (2.5-2.2ubuntu3) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.5/191.5 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 83.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.1/503.1 kB 50.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 65.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 99.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 47.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 22.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.8/599.8 kB 47.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 44.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 28.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 57.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.0/115.0 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 30.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.0 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done
#   Building wheel for dadaptation (pyproject.toml) ... done
#   Building wheel for lycoris-lora (setup.py) ... done
#   Building wheel for library (setup.py) ... done
#   Building wheel for elfinder-client (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 480.5 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 103.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 93.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 91.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 85.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 MB 9.1 MB/s eta 0:00:00

# %%
# @title ## 1.2. Start `File Explorer`
# @markdown This will work in real-time even when you run other cells
import threading
from google.colab import output
from imjoy_elfinder.app import main

open_in_new_tab = False  # @param {type:"boolean"}

def start_file_explorer(root_dir=root_dir, port=8765):
    try:
        main(["--root-dir=" + root_dir, "--port=" + str(port)])
    except Exception as e:
        print("Error starting file explorer:", str(e))


def open_file_explorer(open_in_new_tab=False, root_dir=root_dir, port=8765):
    thread = threading.Thread(target=start_file_explorer, args=[root_dir, port])
    thread.start()

    if open_in_new_tab:
        output.serve_kernel_port_as_window(port)
    else:
        output.serve_kernel_port_as_iframe(port, height="500")

open_file_explorer(open_in_new_tab=open_in_new_tab, root_dir=root_dir, port=8765)

# %% [markdown]
# # II. Pretrained Model Selection

# %%
# @title ## 2.1. Download Available Model
import os

# %store -r

os.chdir(root_dir)

models = {
    "Animefull-final-pruned": "https://huggingface.co/Linaqruf/personal-backup/resolve/main/models/animefull-final-pruned.ckpt",
    "Anything-v3-1": "https://huggingface.co/cag/anything-v3-1/resolve/main/anything-v3-1.safetensors",
    "AnyLoRA": "https://huggingface.co/Linaqruf/stolen/resolve/main/pruned-models/AnyLoRA_noVae_fp16-pruned.safetensors",
    "AnimePastelDream": "https://huggingface.co/Lykon/AnimePastelDream/resolve/main/AnimePastelDream_Soft_noVae_fp16.safetensors",
    "Chillout-mix": "https://huggingface.co/Linaqruf/stolen/resolve/main/pruned-models/chillout_mix-pruned.safetensors",
    "OpenJourney-v4": "https://huggingface.co/prompthero/openjourney-v4/resolve/main/openjourney-v4.ckpt",
    "Stable-Diffusion-v1-5": "https://huggingface.co/Linaqruf/stolen/resolve/main/pruned-models/stable_diffusion_1_5-pruned.safetensors",
}

v2_models = {
    "stable-diffusion-2-1-base": "https://huggingface.co/stabilityai/stable-diffusion-2-1-base/resolve/main/v2-1_512-ema-pruned.safetensors",
    "stable-diffusion-2-1-768v": "https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.safetensors",
    "plat-diffusion-v1-3-1": "https://huggingface.co/p1atdev/pd-archive/resolve/main/plat-v1-3-1.safetensors",
    "replicant-v1": "https://huggingface.co/gsdf/Replicant-V1.0/resolve/main/Replicant-V1.0.safetensors",
    "illuminati-diffusion-v1-0": "https://huggingface.co/IlluminatiAI/Illuminati_Diffusion_v1.0/resolve/main/illuminati_diffusion_v1.0.safetensors",
    "illuminati-diffusion-v1-1": "https://huggingface.co/4eJIoBek/Illuminati-Diffusion-v1-1/resolve/main/illuminatiDiffusionV1_v11.safetensors",
    "waifu-diffusion-1-4-anime-e2": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/wd-1-4-anime_e2.ckpt",
    "waifu-diffusion-1-5-e2": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-fp32.safetensors",
    "waifu-diffusion-1-5-e2-aesthetic": "https://huggingface.co/waifu-diffusion/wd-1-5-beta2/resolve/main/checkpoints/wd-1-5-beta2-aesthetic-fp32.safetensors",
}

installModels = []
installv2Models = []

# @markdown ### SD1.x model
model_name = "AnimePastelDream"  # @param ["", "Animefull-final-pruned", "Anything-v3-1", "AnyLoRA", "AnimePastelDream", "Chillout-mix", "OpenJourney-v4", "Stable-Diffusion-v1-5"]
# @markdown ### SD2.x model
v2_model_name = ""  # @param ["", "stable-diffusion-2-1-base", "stable-diffusion-2-1-768v", "plat-diffusion-v1-3-1", "replicant-v1", "illuminati-diffusion-v1-0", "illuminati-diffusion-v1-1", "waifu-diffusion-1-4-anime-e2", "waifu-diffusion-1-5-e2", "waifu-diffusion-1-5-e2-aesthetic"]

if model_name:
    model_url = models.get(model_name)
    if model_url:
        installModels.append((model_name, model_url))

if v2_model_name:
    v2_model_url = v2_models.get(v2_model_name)
    if v2_model_url:
        installv2Models.append((v2_model_name, v2_model_url))


def install(checkpoint_name, url):
    ext = "ckpt" if url.endswith(".ckpt") else "safetensors"

    hf_token = "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"
    user_header = f'"Authorization: Bearer {hf_token}"'
    # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {pretrained_model} -o {checkpoint_name}.{ext} "{url}"


def install_checkpoint():
    for model in installModels:
        install(model[0], model[1])
    for v2model in installv2Models:
        install(v2model[0], v2model[1])


install_checkpoint()
# Out:
#  *** Download Progress Summary as of Fri Jun  2 07:21:34 2023 ***
# =
# [#4bd455 1.6GiB/5.5GiB(30%) CN:16 DL:168MiB ETA:23s]
# FILE: /content/pretrained_model/AnimePastelDream.safetensors
# -
#
#  *** Download Progress Summary as of Fri Jun  2 07:21:44 2023 ***
# =
# [#4bd455 3.4GiB/5.5GiB(62%) CN:16 DL:181MiB ETA:11s]
# FILE: /content/pretrained_model/AnimePastelDream.safetensors
# -
#
#  *** Download Progress Summary as of Fri Jun  2 07:21:54 2023 ***
# =
# [#4bd455 5.1GiB/5.5GiB(93%) CN:15 DL:170MiB ETA:2s]
# FILE: /content/pretrained_model/AnimePastelDream.safetensors
# -
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4bd455|OK  |   173MiB/s|/content/pretrained_model/AnimePastelDream.safetensors
#
# Status Legend:
# (OK):download completed.

# %%
# @title ## 2.2. Download Custom Model
import os

# %store -r

os.chdir(root_dir)

# @markdown ### Custom model
modelUrls = "https://huggingface.co/ckpt/realistic-vision-v20/blob/main/realisticVisionV20_v20.safetensors"  # @param {'type': 'string'}

def install(url):
    base_name = os.path.basename(url)

    if "drive.google.com" in url:
        os.chdir(pretrained_model)
        # !gdown --fuzzy {url}
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # @markdown Change this part with your own huggingface token if you need to download your private model
        hf_token = "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"  # @param {type:"string"}
        user_header = f'"Authorization: Bearer {hf_token}"'
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {pretrained_model} -o {base_name} {url}
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {pretrained_model} {url}

if modelUrls:
    urls = modelUrls.split(",")
    for url in urls:
        install(url.strip())
# Out:
#  *** Download Progress Summary as of Thu Jun 22 10:31:27 2023 ***
# =
# [#7743ae 2.4GiB/3.5GiB(69%) CN:16 DL:239MiB ETA:4s]
# FILE: /content/pretrained_model/realisticVisionV20_v20.safetensors
# -
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7743ae|OK  |   215MiB/s|/content/pretrained_model/realisticVisionV20_v20.safetensors
#
# Status Legend:
# (OK):download completed.

# %%
# @title ## 2.3. Download Available VAE (Optional)
import os

# %store -r

os.chdir(root_dir)

vaes = {
    "none": "",
    "anime.vae.pt": "https://huggingface.co/Linaqruf/personal-backup/resolve/main/vae/animevae.pt",
    "waifudiffusion.vae.pt": "https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/vae/kl-f8-anime.ckpt",
    "stablediffusion.vae.pt": "https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt",
}
install_vaes = []

# @markdown Select one of the VAEs to download, select `none` for not download VAE:
vae_name = "anime.vae.pt"  # @param ["none", "anime.vae.pt", "waifudiffusion.vae.pt", "stablediffusion.vae.pt"]

if vae_name in vaes:
    vae_url = vaes[vae_name]
    if vae_url:
        install_vaes.append((vae_name, vae_url))


def install(vae_name, url):
    hf_token = "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"
    user_header = f'"Authorization: Bearer {hf_token}"'
    # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {vae_dir} -o {vae_name} "{url}"


def install_vae():
    for vae in install_vaes:
        install(vae[0], vae[1])


install_vae()
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 83bae0|OK  |   256MiB/s|/content/vae/anime.vae.pt
#
# Status Legend:
# (OK):download completed.

# %% [markdown]
# # III. Data Acquisition
#
# You have three options for acquiring your dataset:
#
# 1. Uploading it to Colab's local files.
# 2. Bulk downloading images from Danbooru using the `Simple Booru Scraper`.
# 3. Locating your dataset from Google Drive.

# %%
# @title ## 3.1. Locating Train Data Directory
# @markdown Define the location of your training data. This cell will also create a folder based on your input. Regularization Images is optional and can be skipped.
import os
from IPython.utils import capture

# %store -r

train_data_dir = "/content/LoRA/train_data"  # @param {type:'string'}
reg_data_dir = "/content/LoRA/reg_data"  # @param {type:'string'}

for dir in [train_data_dir, reg_data_dir]:
    if dir:
        with capture.capture_output() as cap:
            os.makedirs(dir, exist_ok=True)
            # %store dir
            del cap

print(f"Your train data directory : {train_data_dir}")
if reg_data_dir:
    print(f"Your reg data directory : {reg_data_dir}")
# Out:
# Your train data directory : /content/LoRA/train_data
# Your reg data directory : /content/LoRA/reg_data

# %%
# !rm -rf /content/LoRA/train_data

# %%
# @title ## 3.2. Unzip Dataset

import os
import shutil
from pathlib import Path

#@title ## Unzip Dataset
# @markdown Use this section if your dataset is in a `zip` file and has been uploaded somewhere. This code cell will download your dataset and automatically extract it to the `train_data_dir` if the `unzip_to` variable is empty.
zipfile_url = "/content/drive/MyDrive/cropped.zip" #@param {type:"string"}
zipfile_name = "zipfile.zip"
unzip_to = "" #@param {type:"string"}

hf_token = "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"
user_header = f'"Authorization: Bearer {hf_token}"'

if unzip_to:
    os.makedirs(unzip_to, exist_ok=True)
else:
    unzip_to = train_data_dir


def download_dataset(url):
    if url.startswith("/content"):
        return url
    elif "drive.google.com" in url:
        os.chdir(root_dir)
        # !gdown --fuzzy {url}
        return f"{root_dir}/{zipfile_name}"
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # !aria2c --console-log-level=error --summary-interval=10 --header={user_header} -c -x 16 -k 1M -s 16 -d {root_dir} -o {zipfile_name} {url}
        return f"{root_dir}/{zipfile_name}"
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {root_dir} -o {zipfile_name} {url}
        return f"{root_dir}/{zipfile_name}"


def extract_dataset(zip_file, output_path):
    if zip_file.startswith("/content"):
        # !unzip -j -o {zip_file} -d "{output_path}"
    else:
        # !unzip -j -o "{zip_file}" -d "{output_path}"


def remove_files(train_dir, files_to_move):
    for filename in os.listdir(train_dir):
        file_path = os.path.join(train_dir, filename)
        if filename in files_to_move:
            if not os.path.exists(file_path):
                shutil.move(file_path, training_dir)
            else:
                os.remove(file_path)


zip_file = download_dataset(zipfile_url)
extract_dataset(zip_file, unzip_to)
os.remove(zip_file)

files_to_move = (
    "meta_cap.json",
    "meta_cap_dd.json",
    "meta_lat.json",
    "meta_clean.json",
)

remove_files(train_data_dir, files_to_move)
# Out:
# Archive:  /content/drive/MyDrive/cropped.zip
#  extracting: /content/LoRA/train_data/cropped.zip
#   inflating: /content/LoRA/train_data/manchaha-ep2-2.jpg
#   inflating: /content/LoRA/train_data/promoter-housewife2.jpg
#   inflating: /content/LoRA/train_data/IMG_1651986981717.jpg
#   inflating: /content/LoRA/train_data/brithday-ep22.jpg
#   inflating: /content/LoRA/train_data/adla-badli-
#   inflating: /content/LoRA/train_data/Chaska-ep52.jpg
#   inflating: /content/LoRA/train_data/y15rnracazpv2.jpg
#   inflating: /content/LoRA/train_data/Gaon-Ki-Biwi-ep12.jpg
#   inflating: /content/LoRA/train_data/Gaon-Ki-Garmi-3ep72.jpg
#   inflating: /content/LoRA/train_data/IMG_16484899495182.jpg
#   inflating: /content/LoRA/train_data/IMG_16614101471782.jpg
#   inflating: /content/LoRA/train_data/Woodpecker_42.jpg
#   inflating: /content/LoRA/train_data/AFTER-SCHOOL6.jpg
#   inflating: /content/LoRA/train_data/gulabo-e023.jpg
#   inflating: /content/LoRA/train_data/IMG_16460210801802.jpg
#   inflating: /content/LoRA/train_data/laachi-ep52.jpg
#   inflating: /content/LoRA/train_data/IMG_16520299176545.jpg
#   inflating: /content/LoRA/train_data/khidki-part-1-ep12.jpg
#   inflating: /content/LoRA/train_data/play-boy-2-fliz2.jpg
#   inflating: /content/LoRA/train_data/IMG_20220208_0749552.jpg
#   inflating: /content/LoRA/train_data/babu-ji-ep22.jpg
#   inflating: /content/LoRA/train_data/IMG_16476256323442.jpg
#   inflating: /content/LoRA/train_data/garmi-ep-32.jpg
#   inflating: /content/LoRA/train_data/download.jpeg-12.jpg
#   inflating: /content/LoRA/train_data/AFTER-SCHOOL2.jpg
#   inflating: /content/LoRA/train_data/IMG_16523833931552.jpg
#   inflating: /content/LoRA/train_data/pahredaar-ep42.jpg
#   inflating: /content/LoRA/train_data/IMG_16562639542213.jpg
#   inflating: /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister2.jpg
#   inflating: /content/LoRA/train_data/Drlily.2022.E042.jpg
#   inflating: /content/LoRA/train_data/IMG_16485344848192.jpg
#   inflating: /content/LoRA/train_data/kamini-ep23.jpg
#   inflating: /content/LoRA/train_data/Farebi-yaar-ep12.jpg
#   inflating: /content/LoRA/train_data/IMG_16575199117152.jpg
#   inflating: /content/LoRA/train_data/Desi-Sabjiwali5.jpg

# %%
# !ls -l /content/LoRA/train_data | grep "^-" | wc -l
# Out:
# 952

# %%
# !ls -1 /content/LoRA/train_data | tail -n 300 | xargs -I {} rm /content/LoRA/train_data/{}
# !ls -l /content/LoRA/train_data | grep "^-" | wc -l
# Out:
# 302

# %%
#@title ## 3.3. Image Scraper (Optional)
import os
import html
from IPython.utils import capture
# %store -r

os.chdir(root_dir)
#@markdown Use `gallery-dl` to scrape images from an imageboard site. Specify the `prompt(s)` by separating them with commas, e.g., `hito_komoru, touhou`.
booru = "Danbooru" #@param ["Danbooru", "Gelbooru", "Safebooru"]
prompt = "" #@param {type: "string"}
#@markdown  You can also specify a `custom_url` instead of using a predefined site.
custom_url = "" #@param {type: "string"}
#@markdown `sub_folder` option can be used to organize the downloaded images into separate folders based on their concept or category.
sub_folder = "" #@param {type: "string"}
user_agent = "gdl/1.24.5"
#@markdown You can limit the number of images to download by using the `--range` option followed by the desired range. For example `1-200`.
range = "1-200" #@param {type: "string"}
write_tags = True #@param {type: "boolean"}
additional_arguments = "--filename /O --no-part" #@param {type: "string"}
#@markdown Set `with_aria_2c` to `True` to scrape images using aria2c.
with_aria_2c = True #@param {type: "boolean"}

tags = prompt.split(',')
tags = '+'.join(tags)

replacement_dict = {" ": "", "(": "%28", ")": "%29", ":": "%3a"}
tags = ''.join(replacement_dict.get(c, c) for c in tags)

if sub_folder == "":
    image_dir = train_data_dir
elif sub_folder.startswith("/content"):
    image_dir = sub_folder
else:
    image_dir = os.path.join(train_data_dir, sub_folder)
    os.makedirs(image_dir, exist_ok=True)

if booru == "Danbooru":
    url = "https://danbooru.donmai.us/posts?tags={}".format(tags)
elif booru == "Gelbooru":
    url = "https://gelbooru.com/index.php?page=post&s=list&tags={}".format(tags)
else:
    url = "https://safebooru.org/index.php?page=post&s=list&tags={}".format(tags)

valid_url = custom_url if custom_url else url

def scrape(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

def pre_process_tags(directory):
    for item in os.listdir(directory):
        item_path = os.path.join(directory, item)
        if os.path.isfile(item_path) and item.endswith(".txt"):
            old_path = item_path
            new_file_name = os.path.splitext(os.path.splitext(item)[0])[0] + ".txt"
            new_path = os.path.join(directory, new_file_name)

            os.rename(old_path, new_path)

            with open(new_path, "r") as f:
                contents = f.read()

            contents = html.unescape(contents)
            contents = contents.replace("_", " ")
            contents = ", ".join(contents.split("\n"))

            with open(new_path, "w") as f:
                f.write(contents)

        elif os.path.isdir(item_path):
            pre_process_tags(item_path)

get_url_config = {
    "get-urls" : True,
    "range" : range if range else None,
    "user-agent" : user_agent
}

scrape_config = {
    "directory" : image_dir,
    "write-tags" : write_tags,
    "range" : range if range else None,
    "user-agent" : user_agent
}

if with_aria_2c:
    scraper_text = os.path.join(root_dir, "scrape_this.txt")
    with capture.capture_output() as cap:
        args = scrape(get_url_config)
        # !gallery-dl "{valid_url}" {args} {additional_arguments}
    with open(scraper_text, "w") as f:
        f.write(cap.stdout)

    os.chdir(image_dir)
    # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -i {scraper_text}

else:
    args = scrape(scrape_config)
    # !gallery-dl "{valid_url}" {args} {additional_arguments}

if write_tags:
    pre_process_tags(train_data_dir)

# %% [markdown]
# # IV. Data Preprocessing

# %%
# @title ## 4.1. Data Cleaning
import os
import random
import concurrent.futures
from tqdm import tqdm
from PIL import Image

# %store -r

os.chdir(root_dir)

test = os.listdir(train_data_dir)
# @markdown This section will delete unnecessary files and unsupported media such as `.mp4`, `.webm`, and `.gif`.
# @markdown Set the `convert` parameter to convert your transparent dataset with an alpha channel (RGBA) to RGB and give it a white background.
convert = False  # @param {type:"boolean"}
# @markdown You can choose to give it a `random_color` background instead of white by checking the corresponding option.
random_color = False  # @param {type:"boolean"}
# @markdown Use the `recursive` option to preprocess subfolders as well.
recursive = False #  @param {type:"boolean"}


batch_size = 32
supported_types = [
    ".png",
    ".jpg",
    ".jpeg",
    ".webp",
    ".bmp",
    ".caption",
    ".npz",
    ".txt",
    ".json",
]

background_colors = [
    (255, 255, 255),
    (0, 0, 0),
    (255, 0, 0),
    (0, 255, 0),
    (0, 0, 255),
    (255, 255, 0),
    (255, 0, 255),
    (0, 255, 255),
]

def clean_directory(directory):
    for item in os.listdir(directory):
        file_path = os.path.join(directory, item)
        if os.path.isfile(file_path):
            file_ext = os.path.splitext(item)[1]
            if file_ext not in supported_types:
                print(f"Deleting file {item} from {directory}")
                os.remove(file_path)
        elif os.path.isdir(file_path) and recursive:
            clean_directory(file_path)

def process_image(image_path):
    img = Image.open(image_path)
    img_dir, image_name = os.path.split(image_path)

    if img.mode in ("RGBA", "LA"):
        if random_color:
            background_color = random.choice(background_colors)
        else:
            background_color = (255, 255, 255)
        bg = Image.new("RGB", img.size, background_color)
        bg.paste(img, mask=img.split()[-1])

        if image_name.endswith(".webp"):
            bg = bg.convert("RGB")
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            bg.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            bg.save(image_path, "PNG")
            print(f" Converted image: {image_name}")
    else:
        if image_name.endswith(".webp"):
            new_image_path = os.path.join(img_dir, image_name.replace(".webp", ".jpg"))
            img.save(new_image_path, "JPEG")
            os.remove(image_path)
            print(f" Converted image: {image_name} to {os.path.basename(new_image_path)}")
        else:
            img.save(image_path, "PNG")

def find_images(directory):
    images = []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".png") or file.endswith(".webp"):
                images.append(os.path.join(root, file))
    return images

clean_directory(train_data_dir)
images = find_images(train_data_dir)
num_batches = len(images) // batch_size + 1

if convert:
    with concurrent.futures.ThreadPoolExecutor() as executor:
        for i in tqdm(range(num_batches)):
            start = i * batch_size
            end = start + batch_size
            batch = images[start:end]
            executor.map(process_image, batch)

    print("All images have been converted")

# %% [markdown]
# ## 4.2. Data Annotation
# You can choose to train a model using captions. We're using [BLIP](https://huggingface.co/spaces/Salesforce/BLIP) for image captioning and [Waifu Diffusion 1.4 Tagger](https://huggingface.co/spaces/SmilingWolf/wd-v1-4-tags) for image tagging similar to Danbooru.
# - Use BLIP Captioning for: `General Images`
# - Use Waifu Diffusion 1.4 Tagger V2 for: `Anime and Manga-style Images`

# %%
#@title ### 4.2.1. BLIP Captioning
#@markdown BLIP is a pre-training framework for unified vision-language understanding and generation, which achieves state-of-the-art results on a wide range of vision-language tasks. It can be used as a tool for image captioning, for example, `astronaut riding a horse in space`.
import os

os.chdir(finetune_dir)

batch_size = 10 #@param {type:'number'}
max_data_loader_n_workers = 2 #@param {type:'number'}
beam_search = True #@param {type:'boolean'}
min_length = 30 #@param {type:"slider", min:0, max:100, step:5.0}
max_length = 75 #@param {type:"slider", min:0, max:100, step:5.0}
#@markdown Use the `recursive` option to process subfolders as well, useful for multi-concept training.
recursive = False #@param {type:"boolean"}
#@markdown Debug while captioning, it will print your image file with generated captions.
verbose_logging = True #@param {type:"boolean"}

config = {
    "_train_data_dir" : train_data_dir,
    "batch_size" : batch_size,
    "beam_search" : beam_search,
    "min_length" : min_length,
    "max_length" : max_length,
    "debug" : verbose_logging,
    "caption_extension" : ".caption",
    "max_data_loader_n_workers" : max_data_loader_n_workers,
    "recursive" : recursive
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python make_captions.py {args}"

os.chdir(finetune_dir)
# !{final_args}
# Out:
# load images from /content/LoRA/train_data
# found 302 images.
# loading BLIP caption: https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# Downloading (…)solve/main/vocab.txt: 232kB [00:00, 1.77MB/s]
# Downloading (…)okenizer_config.json: 100% 28.0/28.0 [00:00<00:00, 40.5kB/s]
# Downloading (…)lve/main/config.json: 100% 570/570 [00:00<00:00, 885kB/s]
# 100% 1.66G/1.66G [00:07<00:00, 233MB/s]
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_large_caption.pth
# BLIP loaded
#   0% 0/31 [00:00<?, ?it/s]/content/LoRA/train_data/Drlily.2022.E012.jpg a man kissing a woman in a blue top and green skirt in a bathroom with a mirror behind her and a woman in a blue top with a green skirt
# /content/LoRA/train_data/Drlily.2022.E03.jpg a woman in a bra top hugging a man in a room with a clock on the wall behind her and a man in a suit on the other side
# /content/LoRA/train_data/Drlily.2022.E032.jpg a man and woman hugging each other in a room with a wall behind them and a painting on the wall behind them and a woman in a bra
# /content/LoRA/train_data/Drlily.2022.E04.jpg a woman in a bra top and a man in a black shirt are sitting on a couch with a remote control in their hand and a man is pointing at the camera
# /content/LoRA/train_data/Drlily.2022.E042.jpg two women sitting in chairs in a room with a red chair and a red chair with a red chair and a red chair with a red chair
# /content/LoRA/train_data/Drlily.2022.E043.jpg a man and woman are sitting on a bed together, one is holding a baby and the other is holding a baby in her arms
# /content/LoRA/train_data/Drlily.2022.E044.jpg a group of women in a room with a bed and a woman in a bra top and a woman in a skirt and a man in a black shirt
# /content/LoRA/train_data/Drlily.2022.E045.jpg a woman in a blue sari sitting in a chair with a dog on the floor in front of her and a cat sitting on the chair
# /content/LoRA/train_data/Farbiishq.2022.E02.jpg a woman in a red top laying on a bed next to a man in a red shirt and black pants with a cell phone in her hand
# /content/LoRA/train_data/Farbiishq.2022.E022.jpg a woman laying on a bed with a red headband on her head and a red flower in her hair and a red flower in her hair
#   3% 1/31 [00:12<06:25, 12.86s/it]/content/LoRA/train_data/Farebi-Yaar-Part-2-Ep5.jpg a man and woman laying on a bed together, one woman is kissing the other while the other is laying down on the bed and the other
# /content/LoRA/train_data/Farebi-Yaar-Part-2-Ep52.jpg a man and woman laying in bed together, one is kissing the other's head and the other is touching her chest and chest
# /content/LoRA/train_data/Farebi-yaar-ep1.jpg a man and woman in a red bra top and black pants are laying on a bed together and kissing each other with their hands on the chest
# /content/LoRA/train_data/Farebi-yaar-ep12.jpg a man and woman are kissing on a couch together, with a man in a red shirt and a woman in a pink dress and a red dress
# /content/LoRA/train_data/Farebi-yaar-ep3.jpg a man and a woman are in bed together, one is rubbing the other's butt and the other is rubbing her face with her
# /content/LoRA/train_data/Farebi-yaar-ep32.jpg a woman is laying on a bed with a man in the background and a man standing behind her and a woman laying on the bed
# /content/LoRA/train_data/Farebi.2022.Leo_.jpg a woman with a big breast is smiling and showing her big tits and nipples in a room with blue curtains and curtains behind her is a window
# /content/LoRA/train_data/Feelings.jpg a woman with a black shirt and a black and white photo of her face and the words feelings on it, and a black and white photo of a woman with a yellow background
# /content/LoRA/train_data/Feelings2.jpg a woman with long hair and a black shirt is looking at the camera with a sad look on her face and the words feelings are in the background
# /content/LoRA/train_data/Firangi-Thakurain-2-ep1.jpg a man and woman kissing in a room with a window behind them and a blue light behind them and a window behind them is a blue light
#   6% 2/31 [00:16<04:04,  8.44s/it]/content/LoRA/train_data/Firangi-Thakurain-ep1.jpg a man and woman are kissing on a bed together, with a pink flower in the background and a pink flower in the foreground
# /content/LoRA/train_data/Firangi-Thakurain-ep12.jpg a woman is kissing a man in a bed with a pink flower on it's head and a man in a red shirt is wearing a gold bracelet
# /content/LoRA/train_data/Firangi-Thakurain-ep2.jpg a couple of people that are kissing each other in a room with a tv screen behind them and a sign that says fram thaak
# /content/LoRA/train_data/Firangi-Thakurain-ep22.jpg a man and woman in a blue bikinis kissing each other in a room with a tv in the background and a sign that says 2 22 22 22
# /content/LoRA/train_data/Gadikitab2.2022.E04.jpg a man and a woman laying on a bed together, reading a book and a cat laying on the floor behind them, with a woman in a pink dress
# /content/LoRA/train_data/Galtiyan-1.jpg a woman is getting her pussy licked by a man in bed with a remote control on her head and a man in the background with a shirt on his lap
# /content/LoRA/train_data/Galtiyan-12.jpg a woman is getting her face shaved by a man in a mirror with a mirror behind her and a man in the background with a mirror behind her
# /content/LoRA/train_data/Gandii-Baat-S07E01.jpg a group of women laying on top of a bed together in underwears and bikinis on a bed with a man and woman in a bikini
# /content/LoRA/train_data/Gaon-Ki-Biwi-ep1.jpg a man laying in bed with a dog on his lap and a cat on his lap, with a green pillow and a green pillow
# /content/LoRA/train_data/Gaon-Ki-Biwi-ep12.jpg a woman in a green blouse is holding a man in a bathtub with a bowl of water in front of her and a man in the background
#  10% 3/31 [00:20<03:12,  6.86s/it]/content/LoRA/train_data/Gaon-Ki-Garmi-3-ep2.jpg a woman sitting next to a man in a red sari and a man in a blue shirt and a purple shirt and a red tie
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep22.jpg a man and a woman sitting next to each other on a couch with a remote control in their hand and a man looking at the camera
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep4.jpg a woman in a green dress is holding a knife and looking at the camera with a caption of palangate on the side
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep6.jpg a woman laying on a bed with a tattoo on her arm and a tattoo on her arm, with the title of the episode titled dilana ted
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep5.jpg a woman with a piercing on her nose and a man behind her with a black background and a gold logo on the top of the image
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep7.jpg a woman in a sari and a man in a suit and tie standing next to each other in a room with a sign that says'tum 3 '
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep72.jpg a man and woman are looking at each other in a mirror together, with the caption of the episode 7 episode 7 on the screen
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep8.jpg a woman in a blue top and a blue skirt with a red and white striped wall behind her and a red and white striped wall
# /content/LoRA/train_data/Garmi2.2022.E01.jpg a man and a woman laying on a couch together, one of them is wearing a bracquet and the other is wearing a thong
# /content/LoRA/train_data/Ghar-Sasur-ep1-.jpg a woman in a bikini top is brushing her hair with a brush and comber in a bathroom with a mirror in the background and a pink sign that says hair
#  13% 4/31 [00:24<02:44,  6.09s/it]/content/LoRA/train_data/Ghar-Sasur-ep2-.jpg a man and a woman in underwear are standing on a bed together and touching each other's butts and legs with a red carpet
# /content/LoRA/train_data/Ghar-Sasur-ep2-2.jpg a woman in a bikini is sitting on a bed while a man is standing next to her and a man is standing next to her
# /content/LoRA/train_data/Ghar-Sasur-ep4.jpg a woman in a bikini is being fucked by a man in a bedroom with a bed and a couch in the background and a man in a blue underwear
# /content/LoRA/train_data/Ghar-Sasur-ep5.jpg a woman in a bra top hugging a man in a bed with a pillow on it's head and a man in a bra top
# /content/LoRA/train_data/Ghar-Sasur-ep52.jpg a couple of people that are hugging each other on a bed together, one person is kissing the other's head and the other is holding her hand
# /content/LoRA/train_data/Ghar-Sasur-ep6.jpg a man and woman hugging each other on a bed in a room with a fireplace and a couch in the background and a man in a red shorts on the foreground
# /content/LoRA/train_data/Ghar-Sasur-ep62.jpg a man and woman kissing on a couch in a living room with a blue couch and a gray couch in the background and a white wall
# /content/LoRA/train_data/Ghar-Sasur-ep7.jpg a man and a woman are laying on a bed together and smiling at each other while a man looks up at the camera and a woman is holding her
# /content/LoRA/train_data/Ghar-Sasur-ep72.jpg a woman laying in bed with a pillow on her head and a man in the background with a blue shirt and a pink shirt on
# /content/LoRA/train_data/Ghar-Sasur-ep73.jpg a man and woman are laying on a bed together and laughing at each other while a man holds a baby in his lap and a woman is holding a man's arms
#  16% 5/31 [00:28<02:28,  5.71s/it]/content/LoRA/train_data/Ghonchu-EP01.jpg a woman in a hoodie is staring at a man in a hoodie with a red light behind her and the words ghon chu
# /content/LoRA/train_data/Golu.2.jpg a man and a woman laying in bed together, one woman is holding a cell phone and the other is laying down on a bed
# /content/LoRA/train_data/Golu.S01E01.jpg a man and a woman in underwear are laying on a bed together and touching each other's butts and legs, with a pink light shining through the window behind them
# /content/LoRA/train_data/Good-Night-ep3.jpg a man and woman kissing in a dark room with lights in the background and a woman in a white dress and a man in a white shirt
# /content/LoRA/train_data/Grand_Masti.jpg a man and woman laying on a bed together, with eyes closed and their eyes closed, with a man holding a woman's hand
# /content/LoRA/train_data/Grand_Masti2.jpg a man and woman are having a sex party together in bed with a man holding a woman's hand over her chest and a woman's chest
# /content/LoRA/train_data/Grand_Masti3.jpg a woman is kissing a man on the bed with a man in the background and a woman in the foreground with a red lipstick on her lips
# /content/LoRA/train_data/Grand_Masti4.jpg a man and a woman are having a sex party together in bed with a man holding a woman's hand over her chest and a woman's chest
# /content/LoRA/train_data/Gubare-Wali-ep1.jpg a man and woman laying on a bed of hay and looking at each other with a smile on their faces and a woman's face
# /content/LoRA/train_data/Gubare-Wali-ep2.jpg a man and woman are in bed together and one is kissing the other's cheek and the other is touching her chest and chest
#  19% 6/31 [00:32<02:15,  5.44s/it]/content/LoRA/train_data/Guest3_Moment.jpg a man and woman kissing each other in a room with a christmas tree in the background and a sign that says sweet shoppe and a
# /content/LoRA/train_data/Guest3_Moment2.jpg a man and woman kissing each other in a photo studio setting with a red bag and a red heart on the chest of the woman
# /content/LoRA/train_data/Gulabo-ep3.jpg a man and woman laying on a bed together, one of them is kissing the other's foreheads and the other is touching her chest
# /content/LoRA/train_data/Gunha-1.jpg a man and woman laying on a bed together, one is kissing the other's cheek and the other is touching her cheek and smiling
# /content/LoRA/train_data/Gunha-Epi-1.jpg a woman laying on a bed with her hands on her chest and a cat laying on her back with her arm around her neck and a woman's neck
# /content/LoRA/train_data/Gupchup.2022.E04.jpg a man is eating a hot dog with a bite out of it and a woman is holding a cell phone to her ear and a man is looking at him
# /content/LoRA/train_data/Gupchup.2022.E042.jpg a group of people in lingersuits are having fun with each other in a room with a window and a blue light behind them
# /content/LoRA/train_data/Gupchup.2022.E043.jpg a man and woman in lingerie hugging each other in a room with a window behind them and a blue light behind them and a curtain
# /content/LoRA/train_data/Gupchup.2022.E044.jpg a man and a woman are kissing in a room with a christmas tree in the background and a christmas tree in the foreground with a christmas tree
# /content/LoRA/train_data/GuptGyani.E02.jpg a woman is kissing a man in the shower while he is taking a shower in the shower room with a shower head on his head
#  23% 7/31 [00:36<02:04,  5.20s/it]/content/LoRA/train_data/Haramkhor-MooDx-Originals.jpg a man and woman laying on a bed together, one of them is touching the other's chest and the other is touching her chest
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister.jpg a group of people are sitting on a bed together and having a sex party with a man and woman in a yellow hat and a yellow shirt
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister2.jpg a man and a woman laying on a bed together, one of them is holding a pillow and the other is holding a cell phone
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister3.jpg a couple of people that are on a bed together with a man and woman in a yellow shirt and orange shorts and a yellow shirt
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister4.jpg a man and a woman are sitting on a bed together and looking at a cell phone in their hands and a man is holding a woman's hand
# /content/LoRA/train_data/Hope-5-.jpg a man and woman sitting on a couch together, with a man holding a baby in his lap and a woman holding a baby in her lap
# /content/LoRA/train_data/Hope-5-2.jpg a man and a woman sitting next to each other in a room with a sign that says pain end on it and a man with a mustache
# /content/LoRA/train_data/Hope-5-3.jpg a woman in a red dress holding a glass of wine and a man in a white shirt and tie sitting next to her on a bed
# /content/LoRA/train_data/Hope-5-4.jpg a man and woman sitting on a bed holding glasses of wine and smiling at each other with a smile on their faces and a man in a white shirt
# /content/LoRA/train_data/IMG_1645678394793.jpg a woman sitting on a couch with a man behind her and a woman holding a cell phone to her ear and a man standing behind her
#  26% 8/31 [00:40<01:55,  5.01s/it]/content/LoRA/train_data/IMG_16456783947932.jpg a woman is hugging a man in a room with a mirror and a door behind her, and a man is holding a woman's hand
# /content/LoRA/train_data/IMG_1645723027396.jpg a man and woman kissing each other in a red mask and red bra top with the words 3x on it and a woman in a red bra top
# /content/LoRA/train_data/IMG_1645797588024.jpg a man and woman kissing each other in a room with a wall behind them and a yellow scarf on the back of the woman's head
# /content/LoRA/train_data/IMG_1645798208137.jpg a man and woman laying on hay in a barn with a baby in their lap and a man kissing her cheek with his hand on the other
# /content/LoRA/train_data/IMG_1645849263340.jpg a group of women in underwear are playing with each other on a bed together and the words,'sexer'is in the middle of the picture
# /content/LoRA/train_data/IMG_16458492633402.jpg a group of young women are having sex in a bathroom together and a man is holding a woman's hand over her head and a woman's face
# /content/LoRA/train_data/IMG_16458492633403.jpg a couple of women and a man are kissing in a bed together with a man in the background and a woman in the fore of the foreground
# /content/LoRA/train_data/IMG_1645882552560.jpg a man and woman laying on a bed together, kissing and smiling at each other, with a man in a black shirt and a black shirt
# /content/LoRA/train_data/IMG_1646021080180.jpg a man and woman are having a sex party in bed together, with the text uncut naughty bhabd on the bottom of the picture
# /content/LoRA/train_data/IMG_16460210801802.jpg a woman is sucking a man's cock on a bed in a red dress and red shoes and a white shirt is laying on the bed
#  29% 9/31 [00:43<01:47,  4.88s/it]/content/LoRA/train_data/IMG_1646124318539.jpg a man and woman kissing each other in a living room with a computer desk and a laptop on the desk behind them and a man holding a woman
# /content/LoRA/train_data/IMG_16461243185392.jpg a man and a woman are kissing in bed together and laughing at each other with a teddy bear in the background and a teddy bear
# /content/LoRA/train_data/IMG_16461243185393.jpg a man and a woman are kissing in a room with a mirror and a door behind them and a woman is holding a man's arm
# /content/LoRA/train_data/IMG_1646215780995.jpg a woman in a red shirt is playing a video game on her phone and pointing at the camera with her finger up and a smile
# /content/LoRA/train_data/IMG_1646229126545.jpg a man and a woman laying on a bed together, one of them is kissing the other is smiling and the other is smiling at the other is looking at the camera
# /content/LoRA/train_data/IMG_1646246053524.jpg a woman in a red bra top laying on a bed next to a man in a striped shirt and black and white striped shirt with a teddy bear
# /content/LoRA/train_data/IMG_16462460535242.jpg a woman in a red bikini laying on a bed with a pillow and a remote control in her hand and a remote control in her hand
# /content/LoRA/train_data/IMG_1646283258662.jpg a woman with red nails and a necklace on her chest is posing for the camera with her hands on her chest and a necklace on her chest
# /content/LoRA/train_data/IMG_1646290081317.jpg a woman in a black bra top kissing a woman in a black bra top on a bed with a window behind her and curtains behind her
# /content/LoRA/train_data/IMG_1646374706287.jpg a man and a boy looking at a cell phone together in a room with a wall behind them and a texting that reads palanga teo blackmail
#  32% 10/31 [00:47<01:40,  4.79s/it]/content/LoRA/train_data/IMG_16463747062872.jpg a woman is looking at a cell phone with a boy in the background and a man in the foreground looking at her phone with a camera
# /content/LoRA/train_data/IMG_1646489000436.jpg a man and woman are kissing while laying on a bed together and having sex on a bed with a man in a leather jacket and a red shirt
# /content/LoRA/train_data/IMG_1646741504585.jpg a man and woman laying in bed together with the words high society written on the side of the picture and the woman is rubbing her chest
# /content/LoRA/train_data/IMG_1646763392422.jpg a man and a woman are hugging in a circle with a sign in the background that says hot house party on it's side
# /content/LoRA/train_data/IMG_1646907302157.jpg a woman with a very big breast is posing for a picture with a man in a suit and tie on her chest and a man in a suit
# /content/LoRA/train_data/IMG_1646914988807.jpg a man and woman kissing each other in a room with a wall behind them and a man with a beard and a woman with a red lipstick onlook
# /content/LoRA/train_data/IMG_16469149888072.jpg a man and woman kissing each other in a room with a red light behind them and a red light behind them and a red light
# /content/LoRA/train_data/IMG_1646932135689.jpg a woman sitting on a bed while a woman points at her face and another woman is sitting on the bed with her hand on her chest
# /content/LoRA/train_data/IMG_16469321356892.jpg two women are talking in a room together, one is pointing at the other's finger and the other is pointing at her hand
# /content/LoRA/train_data/IMG_1647525722699.jpg a woman in a blue bra is holding her breasts up to show her breast area and her hands on her chest and chest, with a blue bra
#  35% 11/31 [00:51<01:33,  4.70s/it]/content/LoRA/train_data/IMG_1647594336917.jpg a cat is sitting on a couch with a cat in it's lap and the caption reads, uncut cat on the couch
# /content/LoRA/train_data/IMG_16475943369172.jpg a group of young men and women are having sex in a bed together and having a good time together with each other and having fun
# /content/LoRA/train_data/IMG_1647595692772.jpg a man and woman kissing each other in a bathroom mirror, with a red wall behind them and a red wall behind them, and a red wall behind them
# /content/LoRA/train_data/IMG_16475956927722.jpg a woman leaning against a wall with her hand on her head and a man leaning against the wall with his arm around her head,
# /content/LoRA/train_data/IMG_1647625632344.jpg a woman is sucking a man's cock on a couch with a dog nearby and a man is holding a dog on his lap
# /content/LoRA/train_data/IMG_16476256323442.jpg a woman with a tube attached to her breast is laying on a couch with a man in the background and a man in the background
# /content/LoRA/train_data/IMG_16476256323443.jpg a group of people are having fun with each other on a couch and a woman is holding a cup of coffee and a man is holding a knife
# /content/LoRA/train_data/IMG_1647785582414.jpg a man and a woman are hugging in a bathroom together, one is wearing a watch and the other is wearing a pink shirt and a pink tank top
# /content/LoRA/train_data/IMG_16477855824142.jpg a man and woman hugging each other in a room with a green wall behind them and a green wall behind them and a green wall
# /content/LoRA/train_data/IMG_1647867067641.jpg a man and woman in underwear are on a bed together and one woman is laying on the bed and the other is laying down on the bed
#  39% 12/31 [00:55<01:27,  4.63s/it]/content/LoRA/train_data/IMG_1647969034589.jpg a woman is being fucked by a man in a room with a man on the bed and a woman on the bed with a knife
# /content/LoRA/train_data/IMG_1648052772770.jpg a man and a woman are kissing on a bed together, with a red curtain behind them and a red curtain behind them, and a red curtains
# /content/LoRA/train_data/IMG_1648105480903.jpg a woman looking out a window with a remote control in her hand and a curtain behind her, with the words charm sukh on it
# /content/LoRA/train_data/IMG_1648489949518.jpg a man and a woman kissing each other in a park area with trees in the background and a man holding a baby in his arms
# /content/LoRA/train_data/IMG_16484899495182.jpg a group of young women are having sex in the pool with a man and a woman in the background and a man in the foreground
# /content/LoRA/train_data/IMG_16484899495183.jpg a couple is kissing in the water with a sign that says love in pompupi on it and a man and woman are kissing
# /content/LoRA/train_data/IMG_16484899495184.jpg a couple of naked women hugging each other in a park with a man in the background and a woman in the foreground hugging her
# /content/LoRA/train_data/IMG_1648490544932.jpg a man laying on a bed with a cat in his lap and a woman laying on the bed with a cat in her lap and a cat on her lap
# /content/LoRA/train_data/IMG_1648531957722.jpg a woman in a bra top is posing for a picture with a mirror behind her and another woman in a bra top is sitting in a chair
# /content/LoRA/train_data/IMG_16485319577222.jpg a man and woman kissing each other in a room with a sign that says call girl master on it's wallpapers and a woman in the background
#  42% 13/31 [00:59<01:22,  4.57s/it]/content/LoRA/train_data/IMG_1648534484819.jpg a woman is giving a blow on a man's face with a large cocker in her mouth and a man's hand
# /content/LoRA/train_data/IMG_16485344848192.jpg a man and a woman are getting fucked by a man in a black shirt and jeans and a pink shirt with a pink nail polish
# /content/LoRA/train_data/IMG_1648752637291.jpg a man and woman riding a motorcycle together in a photo studio setting, with a backdrop of trees and a path in the background,
# /content/LoRA/train_data/IMG_16487526372912.jpg a man and woman riding a bicycle together in a city street with a brick wall behind them and a brick building in the background with a green and red brick wall
# /content/LoRA/train_data/IMG_1648753077722.jpg a woman with long hair and a necklace on her neck is looking at the camera with a serious look on her face and a black background
# /content/LoRA/train_data/IMG_1648912547326.jpg a man and woman kissing in a bathtub with a mirror behind them and a flower on the floor below them and a text reading
# /content/LoRA/train_data/IMG_1648921193271.jpg a woman in a red bikini top standing in front of a mirror with her arms crossed and her eyes closed, with the words bad
# /content/LoRA/train_data/IMG_1648923555473.jpg a man and woman laying on a bed together, hugging and kissing, with the woman's arm around the man's shoulder
# /content/LoRA/train_data/IMG_16489235554732.jpg a man and woman laying in bed together, one is hugging the other's head and the other is sleeping on the bed with her
# /content/LoRA/train_data/IMG_1648924942844.jpg a man and woman are sitting on a bed together, looking at each other and touching noses with their eyes closed, with a man in the woman's face to the other
#  45% 14/31 [01:03<01:17,  4.56s/it]/content/LoRA/train_data/IMG_16489249428442.jpg a man and woman are in bed with a leopard print shirt on and a white tank top on the bed, and a woman is looking at her face to the side
# /content/LoRA/train_data/IMG_1648962796104.jpg a woman in a bikini is standing next to a bed with a baby in it and a woman in a bikini is sitting on the bed
# /content/LoRA/train_data/IMG_16489627961042.jpg a girl sitting on a bed brushing her teeth with a toothbrush in front of a mirror with a reflection of her reflection in the mirror
# /content/LoRA/train_data/IMG_16489627961043.jpg two women in lingersuits are sitting on a bed and looking at their cell phones in a mirror in a hotel room with a bed
# /content/LoRA/train_data/IMG_16489627961044.jpg a man sitting on a bed next to a woman in lingerie and panties on a bed with a mirror in the background and a woman in a mirror
# /content/LoRA/train_data/IMG_16489627961045.jpg a woman in a bikini is looking at another woman in a bra top and panties in a mirror in a room with a window and a curtain
# /content/LoRA/train_data/IMG_16489627961046.jpg a man with a beard sitting in bed next to a woman with a laptop computer on her lap and a lamp on the side of the bed
# /content/LoRA/train_data/IMG_1649005793187.jpg two women are hugging each other in a room with a mirror behind them and a woman in a red dress is standing next to her
# /content/LoRA/train_data/IMG_16490057931872.jpg two women in red dresses are kissing each other in a room with a mirror and a chair in the background and a bed in the foreground
# /content/LoRA/train_data/IMG_1649055910834.jpg a man and a woman laying on a bed together, with the man holding the woman's head and the woman's face
#  48% 15/31 [01:07<01:12,  4.53s/it]/content/LoRA/train_data/IMG_1649179338859.jpg a woman is kissing a young girl on the bed together, both wearing red and blue striped clothes, both wearing gold bangles and bracelets
# /content/LoRA/train_data/IMG_1649358443843.jpg a woman is holding her hand to her face and looking at the camera with a yellow light in the background that reads vjv
# /content/LoRA/train_data/IMG_1649644466657.jpg a woman in a bra top laying on a bed next to a man in a bra top and panties on a bed with a pillow
# /content/LoRA/train_data/IMG_16496444666572.jpg a woman in a bra top laying on a bed with a man in a thong on her chest and a man in a bra top
# /content/LoRA/train_data/IMG_1649730093179.jpg a blurry photo of a person holding a banana in their hand and a banana in their hand, with a blurry background of a banana in the background
# /content/LoRA/train_data/IMG_16497300931792.jpg a woman in a red shirt is sitting on a bed with a blanket on her head and a blanket draped over her shoulders and a pillow
# /content/LoRA/train_data/IMG_16497300931793.jpg a man and woman in a bathroom with a mirror behind them and a towel on the counter next to them, and a towel on the wall
# /content/LoRA/train_data/IMG_16497300931794.jpg a man in a red and white striped shorts is holding a teddy bear in his arms and looking at his reflection in a mirror in a mirror
# /content/LoRA/train_data/IMG_1649816492417.jpg a man and woman laying on a bed together, kissing and kissing each other, with a vase of flowers in the background behind them
# /content/LoRA/train_data/IMG_1649841886166.jpg a man and a woman are laying on a bed together and kissing each other with a watch on their wrist and a watch on their wrist
#  52% 16/31 [01:11<01:07,  4.50s/it]/content/LoRA/train_data/IMG_1649963022108.jpg a man kissing a woman's forehead in a scene from the movie the devil in the closet, which is being watched by a woman
# /content/LoRA/train_data/IMG_1650038990330.jpg a man and woman are laying on a bed together and having sex on the bed with a man who is holding a woman's hand
# /content/LoRA/train_data/IMG_1650074240285.jpg a man and woman are kissing in bed together, with a red blanket on the bed behind them and a red blanket on the floor
# /content/LoRA/train_data/IMG_1650074657811.jpg a woman is giving a man a blow on his face and he is rubbing his face with his hand and he is rubbing his chest
# /content/LoRA/train_data/IMG_16500746578112.jpg a man is getting his hair brushed by a woman in a hospital bed and a woman is holding a hair dryer in her hand
# /content/LoRA/train_data/IMG_1650075459688.jpg a man and woman kissing each other in a room with a wall behind them and a wall behind them with a white wall behind them
# /content/LoRA/train_data/IMG_16500754596882.jpg a man and woman kissing each other in bed with a white sheet covering them in the background and a white sheet covering them in the foreground
# /content/LoRA/train_data/IMG_1650078871392.jpg a man and a woman in lingerie laying on a bed together, one woman is touching the other's chest and the other is touching her chest
# /content/LoRA/train_data/IMG_16500788713922.jpg a man and a woman in lingerie kissing on a bed together, with a man in a black bra top and a woman in a black bra
# /content/LoRA/train_data/IMG_1650330618284.jpg a woman in a bikini is kissing a man in a room with a window in the background and a window behind her, and a man in the foreground
#  55% 17/31 [01:15<01:02,  4.47s/it]/content/LoRA/train_data/IMG_16503306182842.jpg a man and woman kissing each other in a room with a wall behind them and a mirror behind them and a woman in a pink dress
# /content/LoRA/train_data/IMG_1650331276485.jpg a woman laying in bed next to a man who is laying down on a bed with a pink blanket on it and a lamp on
# /content/LoRA/train_data/IMG_1650558830731.jpg a man and a woman are sitting on a bed together, one is holding the other's head and the other is laying on the bed
# /content/LoRA/train_data/IMG_1650642170805.jpg a man and woman laying on a bed together and kissing each other with a smile on their faces and eyes closed, with a purple background
# /content/LoRA/train_data/IMG_1650736011315.jpg a man and woman kissing in the shower together, with a shower head in the background and a shower head in the foreground,
# /content/LoRA/train_data/IMG_1650791074824.jpg a man and a woman are in a room together, one is touching the other's chest and the other is touching her chest
# /content/LoRA/train_data/IMG_1650965196175.jpg a woman in a black bra top brushing her hair in front of a mirror with a man in the background and a woman in a yellow shirt
# /content/LoRA/train_data/IMG_16509651961752.jpg a woman is brushing her hair in the mirror while holding a cell phone in her hand and looking at her reflection in the mirror,
# /content/LoRA/train_data/IMG_16509651961753.jpg a man and a woman are in a bedroom together, one is brushing her hair and the other is brushing her hair with a towel
# /content/LoRA/train_data/IMG_1651169148935.jpg a woman in a bikini is brushing her teeth while a man looks on in the background with a towel on his head and a man with a beard
#  58% 18/31 [01:19<00:57,  4.44s/it]/content/LoRA/train_data/IMG_16511691489352.jpg a man and a woman are looking at each other in a bedroom with a wallpapered wall behind them and a bed with a window
# /content/LoRA/train_data/IMG_1651174228352.jpg a woman in a brown top and a man in a white shirt and a woman in a brown top and a man in a white shirt
# /content/LoRA/train_data/IMG_1651174876374.jpg a man and woman kissing each other in a room with a couch and a chair in the background and a wall behind them with a window
# /content/LoRA/train_data/IMG_16511748763742.jpg a man and a woman kissing each other in a room with a shelf full of toys behind them and a sign that says club club
# /content/LoRA/train_data/IMG_1651250163788.jpg a man and a woman laying on a bed together, one of them is wearing a bikini and the other is wearing a panties and a shirt
# /content/LoRA/train_data/IMG_16512501637882.jpg a man and woman laying in bed together and having sex on the bed with a remote control in their hand and a remote control in their hand
# /content/LoRA/train_data/IMG_1651298588976.jpg a man and woman are in bed with a pink blanket on their backs and a pink blanket on their shoulders, both of them is covered with a pink
# /content/LoRA/train_data/IMG_1651429214970.jpg a man and woman laying on a bed together, with a man kissing his forehead and a woman laying on the bed with her head
# /content/LoRA/train_data/IMG_1651517635956.jpg a man holding a woman in his arms in a forest with trees in the background and a woman in the foreground holding a man
# /content/LoRA/train_data/IMG_16515176359562.jpg a cat is sitting on a couch and looking at a remote control in the dark with a blurry background of a person holding a remote control
#  61% 19/31 [01:23<00:52,  4.41s/it]/content/LoRA/train_data/IMG_16515176359563.jpg a man and woman are hugging in the woods together, with a man holding a woman's head in the air and a woman's face
# /content/LoRA/train_data/IMG_1651520075087.jpg a woman is touching another woman's shoulder in a room with a mirror and a wall behind her, and the words love next door
# /content/LoRA/train_data/IMG_16515200750872.jpg a woman is helping another woman with her tie in a room with a wallpaper and a sign that says,'tu'tum tum tum tum tum tum
# /content/LoRA/train_data/IMG_1651612524734.jpg a man and woman are laying on a bed together and having sex in bed with a teddy bear on the bed and a stuffed animal
# /content/LoRA/train_data/IMG_1651762340451.jpg a man and woman hugging each other in a room with a red wall behind them and a blue door behind them and a red wall behind them
# /content/LoRA/train_data/IMG_1651762920582.jpg a man and a woman in underwear hugging each other in a bathroom with a window behind them and a wall behind them with a window
# /content/LoRA/train_data/IMG_1651777279287.jpg a woman in a red dress is holding a knife in her mouth and a man in a black shirt is behind her and a man in a red shirt
# /content/LoRA/train_data/IMG_1651854073336.jpg a woman in a red dress is sitting on a man's stomach in a room with pictures on the wall and a man laying on the floor
# /content/LoRA/train_data/IMG_16518540733362.jpg a woman in a bikini top is looking at her cell phone while wearing a pair of earrings and a pair of earrings with a pink bra
# /content/LoRA/train_data/IMG_1651984085031.jpg a woman in a black dress posing for a picture with a pink background and a text that reads booah aah aah aah fuck
#  65% 20/31 [01:28<00:48,  4.42s/it]/content/LoRA/train_data/IMG_1651986981717.jpg a man and woman are hugging and kissing in bed together, with a woman covering her face with her hands and a man holding her head
# /content/LoRA/train_data/IMG_1652029917654.jpg a woman with a cell phone in her hand and a blue umbrella in the background with a blue and white umbrella in the foreground
# /content/LoRA/train_data/IMG_16520299176542.jpg a group of people laying on a bed together with a teddy bear in their lap and a woman holding a teddy bear in her lap
# /content/LoRA/train_data/IMG_16520299176543.jpg a woman is kissing a man on the cheek with a party hat on his head and a party hat on his head is on his head
# /content/LoRA/train_data/IMG_16520299176544.jpg a couple of women sitting on top of a bed together, one of them is kissing the other's cheek and the other is touching her
# /content/LoRA/train_data/IMG_16520299176545.jpg a man and woman sitting on a bed together, one of them is holding the other's arm and the other is holding the other
# /content/LoRA/train_data/IMG_1652032127110.jpg a woman is laying in bed with a man holding her hand over her head and a man is holding her hand over her head and a woman's chest
# /content/LoRA/train_data/IMG_1652098098040.jpg a man and a woman are kissing on a table with cards on it and a laptop in the background with a woman's hand
# /content/LoRA/train_data/IMG_1652376596091.jpg a man and woman are laying in bed together and touching each other's hands and smiling at each other's eyes, with a red pillow behind them
# /content/LoRA/train_data/IMG_16523765960912.jpg a man and a woman kissing each other in bed with a baby in his lap and a man holding a baby in his lap and a woman's lap
#  68% 21/31 [01:32<00:44,  4.41s/it]/content/LoRA/train_data/IMG_1652383393155.jpg a man and a woman in a hospital room holding hands and looking at each other with a stethoscope on their arm and a stethoscope
# /content/LoRA/train_data/IMG_16523833931552.jpg a woman in a red dress holding a mans hand and smiling at him in a bathroom mirror with a man in a white shirt and tie
# /content/LoRA/train_data/IMG_1652455805656.jpg a woman with long hair and a scarf on a cell phone in front of a picture of a woman with long hair and a scarf on a cell phone
# /content/LoRA/train_data/IMG_16524558056562.jpg a man and woman kissing each other in a room with a painting on the wall behind them and a woman in a pink dress and a man in a blue shirt
# /content/LoRA/train_data/IMG_16524558056563.jpg a man and woman kissing each other in a room with curtains and a window behind them, and a man in a white shirt and tie
# /content/LoRA/train_data/IMG_1653199888630.jpg a man sitting on a couch with a laptop computer in his lap and a remote control in his hand and a remote control in his other hand
# /content/LoRA/train_data/IMG_16531998886302.jpg a woman sitting in bed with a laptop computer on her lap and a teddy bear on the bed behind her, with a teddy bear
# /content/LoRA/train_data/IMG_1653880199441.jpg a man and woman kissing on a bed in a bedroom with a blue blanket on it and a white wall behind them and a blue bed
# /content/LoRA/train_data/IMG_16538801994412.jpg a man and woman sitting on a bed kissing each other with a smile on their faces and a blue and white striped blanket behind them
# /content/LoRA/train_data/IMG_1654825844230.jpg a man and a woman sitting on a bed with a book in their hands and a man reading a book in his lap with a clock above them
#  71% 22/31 [01:36<00:39,  4.40s/it]/content/LoRA/train_data/IMG_16548258442302.jpg a woman sitting on a bed with a red dress on and a man sitting on a couch in the background with the words all alone
# /content/LoRA/train_data/IMG_1654876467539.jpg a man and woman laying on a bed together, with the capt,'the best way to kiss is to kiss'in the middle of the picture
# /content/LoRA/train_data/IMG_1655489609125.jpg a woman in a red bikini is hugging a man in a red bra top and tie around his neck and chest and a man in a black shirt is holding a cell phone
# /content/LoRA/train_data/IMG_16554896091252.jpg a man and woman kissing in a bathroom with a mirror behind them and a man in a watch on his wrist and a woman in a dress
# /content/LoRA/train_data/download.jpeg-6.jpg a woman in a white dress is posing for a picture in a mirror with a necklace on her neck and a necklace on her neck
# /content/LoRA/train_data/download.jpeg-9.jpg a woman in a gray dress is standing next to a man in a blue shirt and a blue shirt and a blue shirt and a blue shirt
# /content/LoRA/train_data/download.jpeg.jpg a man and woman in a kitchen with a wooden stove and a stove top oven in the background with a sign that says lahore of lahcore po
# /content/LoRA/train_data/dream-girl-ep3.jpg a man and a woman in bed with the words dream girl on the cover of the movie's poster, which is in hindi
# /content/LoRA/train_data/dream-girl-ep32.jpg a woman sitting on a couch next to a man in a red shirt and a man in a red shirt and a woman in a red shirt
# /content/LoRA/train_data/dream-girl-ep6.jpg a woman standing next to a man in a room with a window behind her and a man looking at her with a smile on his face
#  74% 23/31 [01:41<00:35,  4.41s/it]/content/LoRA/train_data/dream-girl-ep62.jpg a man and woman in a room with a wall behind them and a text that reads dream in hindi on the wall behind them is a man and a woman
# /content/LoRA/train_data/duhan-e01.jpg a man and a woman laying on a bed together, smiling and laughing at each other, with a purple background behind them, and a purple light
# /content/LoRA/train_data/e4.jpg a woman in a pink dress pointing at the camera with a red text over her head and a green background with trees and bushes in the background
# /content/LoRA/train_data/e42.jpg a man and a woman are talking in front of a tree and bushes with a red brick building in the background and a text overlay reads episode 4
# /content/LoRA/train_data/e43.jpg a man in a blue shirt and glasses standing in front of a bush with a red sign that says olo originals on it
# /content/LoRA/train_data/ee9.jpg a man holding a picture of himself in a picture frame with a hand on it and a hand holding a picture of himself in a picture frame
# /content/LoRA/train_data/ee92.jpg a woman holding up two photos of a man and a woman with a man in the background holding up two photos of a woman and a man
# /content/LoRA/train_data/ek-ajnabee-ep2.jpg a man and a woman laying on a bed together, one of them is kissing the other is touching her chest and the other is touching her chest
# /content/LoRA/train_data/ek-sath-teen-teen-ep1.jpg a woman in a bikini laying on a bed next to a man in a bra top and panties on his stomach and holding a teddy bear
# /content/LoRA/train_data/ek-sath-teen-teen-ep12.jpg a woman in a bikini laying on a bed next to a man in a suit and tie on a bed with a cell phone in his hand
#  77% 24/31 [01:45<00:30,  4.40s/it]/content/LoRA/train_data/ek-sath-teen-teen-ep2.jpg a woman in a blue dress is biting a mans ear with a knife in her mouth and a man in a blue shirt is looking at her
# /content/LoRA/train_data/ep22.jpg a man and a woman are posing naked in a bathroom together, with a mirror behind them and a chair in the background, and a woman is holding a man's arm around her
# /content/LoRA/train_data/ep222.jpg a man and a woman are sitting on a bed together and having sex in a hotel room with a bed and a table in the background
# /content/LoRA/train_data/ep3-1.jpg a woman with a ring on her hand and a man with a ring on his hand, with the words charm sukkt kamrp
# /content/LoRA/train_data/ep3.jpg a man and a woman are posing for a picture together in a photo studio, with a red light behind them and a blue background
# /content/LoRA/train_data/ep32.jpg a man and a woman hugging each other in a movie poster with the title of the novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel novel
# /content/LoRA/train_data/epp1.jpg a woman in a blue top is holding a cell phone up to her ear and looking at her phone screen with a smile on her face
# /content/LoRA/train_data/favoriteteacherep-04-mkv-20220211-072046-587.jpg a woman in a red bra top sitting on a bed next to a man in a blue shirt and black pants and a red bra top
# /content/LoRA/train_data/flat-screen-ep1.jpg a woman is hugging a man on a bed in a bedroom with a white wall behind her and a man in a black shirt is laying on the bed
# /content/LoRA/train_data/flat-screen-ep12.jpg a man and woman are sitting on a bed together, one is holding the other's head and the other is holding a pillow
#  81% 25/31 [01:54<00:27,  4.57s/it]/content/LoRA/train_data/flat-screen-ep2.jpg a woman in a bikini top leaning against a wall with her hands on her stomach and a man in a suit standing next to her
# /content/LoRA/train_data/flat-screen-ep22.jpg a man in a pink shirt is hugging a woman in a pink robe in a bathroom with a white tub and a pink towel on the floor
# /content/LoRA/train_data/fragrance.jpg a man and woman are sitting on a bed together and looking at a cell phone together, both of them is wearing a pink shirt
# /content/LoRA/train_data/fragrance2.jpg a man is helping a woman with her breasts on a bed in a red dress and stockings on her chest and a red headband
# /content/LoRA/train_data/fuljhadi-bhabhi-ep1.jpg a couple of people that are hugging each other in a room with a sign that says top 10 on it and a picture of a man and woman kissing a woman
# /content/LoRA/train_data/fuljhadi-bhabhi-ep12.jpg a man and a woman kissing in front of a mirror with the words sex in the mirror on it's side of the picture
# /content/LoRA/train_data/gachi4.jpg a man and woman are looking at each other in a scene from the movie tum tum tum tum tum tum
# /content/LoRA/train_data/gachi42.jpg a man and woman are kissing in a room with a sign that says,'the u u originals'and a red circle
# /content/LoRA/train_data/gachi5.jpg a woman in a sari and a man in a suit and tie are looking at each other in a movie poster with the title of the film
# /content/LoRA/train_data/gachi52.jpg a woman with a nose piercing and a red shirt is looking at the camera with a yellow text that reads,'watchi '
#  84% 26/31 [01:58<00:22,  4.56s/it]/content/LoRA/train_data/gachi6.jpg a woman in a sari looking at the camera with a man in the background and a sign that says,'olu originals a '
# /content/LoRA/train_data/gandi-baat-ep2.jpg a man and a woman are kissing in a room with a wall behind them and a red wall behind them and a red wall behind them
# /content/LoRA/train_data/gao-ki-malai-ep2.jpg a man and woman laying on a bed together, with a red rose petals on the bed and a red rose petals on the bed
# /content/LoRA/train_data/garmi-ep-3.jpg a man and woman are hugging each other in a room with a wall behind them and a mirror behind them and a woman in a black shirt
# /content/LoRA/train_data/garmi-ep-32.jpg a man and woman in a colorful shirt and panties posing for a picture together in front of a mirror with a man holding a woman
# /content/LoRA/train_data/ghar-ka-call-boy-ep4.jpg a man and a woman in underwear are kissing on a bed with a man in a suit and a woman in a bra top and skirt
# /content/LoRA/train_data/ghar-ka-call-boy-ep42.jpg a woman in a brown dress holding a blue object in her hand and a man in a blue shirt and tie standing next to her
# /content/LoRA/train_data/ghar-ka-call-boy-ep6.jpg a woman in a bikini top is sitting on a bed with a man in the background and a man in the foreground with a cell phone
# /content/LoRA/train_data/ghar-ka-call-boy-ep62.jpg a group of women are hugging and kissing each other in bed together, with one woman holding her head to her chest and the other
# /content/LoRA/train_data/gidgboz2.jpg a woman is touching a man's head while he is holding a cell phone in his hand and he is wearing a pink blouse
#  87% 27/31 [02:02<00:18,  4.55s/it]/content/LoRA/train_data/gidgboz22.jpg a man and a woman are hugging each other in a room with a wall behind them and a woman is wearing a pink shirt and blue dress
# /content/LoRA/train_data/good-luck-ep4.jpg a couple of men are hugging each other in a room with a wallpapered wall behind them and a red chair in the background
# /content/LoRA/train_data/good-luck-ep42.jpg a man and woman in underwear are hugging and kissing in a bedroom with a wall behind them and a man with a tattoo on his chest
# /content/LoRA/train_data/gulabo-e02.jpg a statue of a bird with wings spread out and a man in a hat standing behind it with a camera in hand and a blurry background
# /content/LoRA/train_data/gulabo-e022.jpg a cat is sitting on a bed with a person holding a remote control in its hand and a blurry image of a cat in the background
# /content/LoRA/train_data/gulabo-e023.jpg a woman in a blue dress is sitting on a bed with a man in a blue shirt and a man in a blue shirt and a blue shirt
# /content/LoRA/train_data/gulabo-e024.jpg a man is kissing a woman in a blue dress and a red bracelet on her neck and a blue dress on her chest and a red bracelet
# /content/LoRA/train_data/guptrog-ep2.jpg a man and woman hugging each other in a field of flowers with the words'tum tum tum tum tum tum '
# /content/LoRA/train_data/halala-ep1.jpg a man and woman in lingerie laying on a bed together, one of them is touching the other's chest and the other is touching her face
# /content/LoRA/train_data/halala-ep12.jpg a woman laying on a bed with a cell phone in her hand and a man in the background with a cell phone in his hand
#  90% 28/31 [02:07<00:13,  4.54s/it]/content/LoRA/train_data/hamari-sapna-bhabhi-ep3.jpg a woman in a red top laying on a bed next to a man in a red shirt and red shorts and a red headband
# /content/LoRA/train_data/hanymoon-2.jpg a man and woman are sitting on a bed together and kissing each other with petals scattered around them and a man in a blue suit
# /content/LoRA/train_data/hanymoon-22.jpg a man and woman are posing for a picture together in a room with red curtains and a red curtain behind them and a woman with a man with a blue jacket and a gold necklace and a gold necklace
# /content/LoRA/train_data/hast-Maithoon-ep2.jpg a group of people are having fun in a bathroom together, with a man and woman in the background and a woman in the foreground
# /content/LoRA/train_data/hast-Maithoon-ep22.jpg a woman is laying down with her head on a pillow and a remote control in her hand and a tv in the background with a window
# /content/LoRA/train_data/hast-Maithoon-ep23.jpg a man and woman are having a sex party together on a bed with a man in the background and a woman in the foreground
# /content/LoRA/train_data/hawash-ep1.jpg a man and a woman are laying on a bed together and having sex on the bed with a man in the background and a woman in the foreground
# /content/LoRA/train_data/hb5v1a3uojcf.jpg a man is holding a piece of cake with chocolate frosting on it and a knife in front of it and a plate with a cake on it
# /content/LoRA/train_data/hgds.jpg a man and a woman sitting on a bed with a mask on their head and a man in a red shirt and a woman in a pink shirt
# /content/LoRA/train_data/hgds2.jpg a woman sitting on a bed next to a man in a yellow shirt and black pants and a pink dress with a gold necklace and a necklace
#  94% 29/31 [02:12<00:09,  4.57s/it]/content/LoRA/train_data/hh4.jpg a woman with a braid in a sari and a name on it that says pudhu pudhu pudhu pudh
# /content/LoRA/train_data/hh5.jpg a woman sleeping in bed with a stuffed animal next to her and a teddy bear on the pillow next to her head and a blue blanket
# /content/LoRA/train_data/hh52.jpg a woman is talking to a man in a blue sari and a man in a blue shirt is sitting on a couch and a man is holding a guitar
# /content/LoRA/train_data/hh53.jpg a man and woman sitting on a couch with a blue umbrella in their hands and a man holding a baby in his lap and a woman holding a baby
# /content/LoRA/train_data/honey-trap-ep1.jpg a man and woman hugging each other in a room with a mirror behind them and the words holi holi on the wall above them
# /content/LoRA/train_data/hope-ep1.jpg a man and woman laying on a bed together, one woman is touching the other's chest and the other is touching her belly
# /content/LoRA/train_data/hope-ep2.jpg a woman in a red top hugging a man in a bed with a brick wall behind her and a brick wall behind her and a brick wall
# /content/LoRA/train_data/hope-ep22.jpg a woman in a red top is kissing a man in a red shirt and a red shirt and a red shirt on a bed with a brick wall
# /content/LoRA/train_data/hope-ep4.jpg a man and woman in a river kissing and kissing each other with rocks in the background and water around them and rocks in the foreground
# /content/LoRA/train_data/iloveyouep1.jpg a woman with glasses is looking at the camera and has a message on it that says i love you a lot, and a picture of a woman with glasses
# 100% 31/31 [02:17<00:00,  4.43s/it]
# /content/LoRA/train_data/iloveyouep2.jpg a man sitting on a beach with the sun setting behind him and the words yoga written in pink on the front of the image and a red
# /content/LoRA/train_data/iloveyouep22.jpg a woman standing on a beach next to the ocean with the words love on it and a picture of a woman in a red dress
# done!

# %%
#@title ### 4.2.2. Waifu Diffusion 1.4 Tagger V2
import os
# %store -r

os.chdir(finetune_dir)

#@markdown [Waifu Diffusion 1.4 Tagger V2](https://huggingface.co/spaces/SmilingWolf/wd-v1-4-tags) is a Danbooru-styled image classification model developed by SmilingWolf. It can also be useful for general image tagging, for example, `1girl, solo, looking_at_viewer, short_hair, bangs, simple_background`.
batch_size = 10 #@param {type:'number'}
max_data_loader_n_workers = 2 #@param {type:'number'}
model = "SmilingWolf/wd-v1-4-convnextv2-tagger-v2" #@param ["SmilingWolf/wd-v1-4-convnextv2-tagger-v2", "SmilingWolf/wd-v1-4-swinv2-tagger-v2", "SmilingWolf/wd-v1-4-convnext-tagger-v2", "SmilingWolf/wd-v1-4-vit-tagger-v2"]
#@markdown Use the `recursive` option to process subfolders as well, useful for multi-concept training.
recursive = False #@param {type:"boolean"}
#@markdown Debug while tagging, it will print your image file with general tags and character tags.
verbose_logging = True #@param {type:"boolean"}
#@markdown Separate `undesired_tags` with comma `(,)` if you want to remove multiple tags, e.g. `1girl,solo,smile`.
undesired_tags = "" #@param {type:'string'}
#@markdown  Adjust `general_threshold` for pruning tags (less tags, less flexible). `character_threshold` is useful if you want to train with character tags, e.g. `hakurei reimu`.
general_threshold = 0.35 #@param {type:"slider", min:0, max:1, step:0.05}
character_threshold = 0.8 #@param {type:"slider", min:0, max:1, step:0.05}

config = {
    "_train_data_dir": train_data_dir,
    "batch_size": batch_size,
    "repo_id": model,
    "recursive": recursive,
    "remove_underscore": True,
    "general_threshold": general_threshold,
    "character_threshold": character_threshold,
    "caption_extension": ".txt",
    "max_data_loader_n_workers": max_data_loader_n_workers,
    "debug": verbose_logging,
    "undesired_tags": undesired_tags
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python tag_images_by_wd14_tagger.py {args}"

os.chdir(finetune_dir)
# !{final_args}
# Out:
# downloading wd14 tagger model from hf_hub. id: SmilingWolf/wd-v1-4-convnextv2-tagger-v2
# Downloading keras_metadata.pb: 100% 477k/477k [00:00<00:00, 17.7MB/s]
# Downloading saved_model.pb: 100% 6.17M/6.17M [00:00<00:00, 91.5MB/s]
# Downloading (…)in/selected_tags.csv: 254kB [00:00, 1.93MB/s]
# Downloading (…).data-00000-of-00001: 100% 388M/388M [00:02<00:00, 145MB/s]
# Downloading variables.index: 100% 25.5k/25.5k [00:00<00:00, 1.55MB/s]
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# found 302 images.
#   0% 0/31 [00:00<?, ?it/s]
# /content/LoRA/train_data/Drlily.2022.E012.jpg:
#   Character tags:
#   General tags: 1girl, breasts, multiple girls, large breasts, black hair, 1boy, navel, 2girls, cleavage, jewelry, closed eyes, hetero, earrings, midriff, dark skin, yuri, bracelet, crop top, grabbing, ring, breast grab, denim, kiss, jeans, hoop earrings, realistic
#
# /content/LoRA/train_data/Drlily.2022.E03.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, looking at viewer, smile, large breasts, brown hair, shirt, black hair, 1boy, cleavage, jewelry, underwear, hetero, earrings, indoors, bra, mole, blurry, makeup, black bra, watch, hoop earrings, realistic, wristwatch
#
# /content/LoRA/train_data/Drlily.2022.E032.jpg:
#   Character tags:
#   General tags: black hair, 1boy, male focus, multiple boys, tears, 2boys, hug, crying, realistic
#
# /content/LoRA/train_data/Drlily.2022.E04.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, closed mouth, upper body, indoors, blurry, depth of field, blurry background
#
# /content/LoRA/train_data/Drlily.2022.E042.jpg:
#   Character tags:
#   General tags: 1girl, solo, sitting, indoors, chair, horror (theme)
#
# /content/LoRA/train_data/Drlily.2022.E043.jpg:
#   Character tags:
#   General tags: 1girl, shirt, 1boy, ass, barefoot, pants, indoors, blurry
#
# /content/LoRA/train_data/Drlily.2022.E044.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, 1boy, jewelry, male focus, barefoot, pants, bracelet, kneeling, parody, topless male
#
# /content/LoRA/train_data/Drlily.2022.E045.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, skirt, shirt, black hair, sitting
#
# /content/LoRA/train_data/Farbiishq.2022.E02.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, 1boy, underwear, panties, dark skin, dark-skinned female, close-up, very dark skin
#
# /content/LoRA/train_data/Farbiishq.2022.E022.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, 1boy, closed eyes, male focus, lying, lips, realistic, nose, head back
#   3% 1/31 [00:05<02:40,  5.35s/it]
# /content/LoRA/train_data/Farebi-Yaar-Part-2-Ep5.jpg:
#   Character tags:
#   General tags: 1girl, breasts, short hair, black hair, 1boy, jewelry, underwear, closed eyes, hetero, lying, on back, necklace, bracelet, grabbing, oral, breast grab, realistic
#
# /content/LoRA/train_data/Farebi-Yaar-Part-2-Ep52.jpg:
#   Character tags:
#   General tags: 1girl, short hair, shirt, black hair, 1boy, jewelry, closed eyes, hetero, green hair, barefoot, sex, bracelet, bottomless, facial hair, kiss, beard
#
# /content/LoRA/train_data/Farebi-yaar-ep1.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, black hair, 1boy, jewelry, underwear, closed eyes, hetero, lying, pants, dark skin, bra, bracelet, facial hair, grabbing, dark-skinned male, ring, breast grab, denim, beard, jeans, realistic, manly
#
# /content/LoRA/train_data/Farebi-yaar-ep12.jpg:
#   Character tags:
#   General tags: 1girl, black hair, dress, jewelry, closed eyes, lying, parted lips, dark skin, on back, bracelet, dark-skinned female, ring, pink dress, veil, realistic
#
# /content/LoRA/train_data/Farebi-yaar-ep3.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, brown hair, black hair, 1boy, jewelry, closed mouth, closed eyes, male focus, nude, earrings, facial hair, parody, beard, meme, realistic, mustache, what, fine art parody
#
# /content/LoRA/train_data/Farebi-yaar-ep32.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, jewelry, male focus, nude, earrings, bracelet, looking down, ring, realistic
#
# /content/LoRA/train_data/Farebi.2022.Leo_.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, large breasts, black hair, jewelry, closed eyes, nude, dark skin, dark-skinned female, lips, ring, covering, covering breasts, realistic
#
# /content/LoRA/train_data/Feelings.jpg:
#   Character tags:
#   General tags: long hair, multiple girls, monochrome, greyscale, 3girls, english text, parody, realistic
#
# /content/LoRA/train_data/Feelings2.jpg:
#   Character tags:
#   General tags: solo, 1boy, monochrome, yellow eyes, greyscale, male focus, parody, realistic
#
# /content/LoRA/train_data/Firangi-Thakurain-2-ep1.jpg:
#   Character tags:
#   General tags: 1girl, short hair, open mouth, brown hair, black hair, 1boy, jewelry, underwear, closed eyes, hetero, earrings, dark skin, bra, bracelet, grabbing, breast grab, kiss, realistic
#   6% 2/31 [00:06<01:30,  3.13s/it]
# /content/LoRA/train_data/Firangi-Thakurain-ep1.jpg:
#   Character tags:
#   General tags: 1girl, solo, jewelry, necklace, nail polish, bracelet, fingernails, ring, close-up, pink nails, realistic
#
# /content/LoRA/train_data/Firangi-Thakurain-ep12.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, closed eyes, necklace, nail polish, bracelet, lips, parody, pink nails, reflection, realistic
#
# /content/LoRA/train_data/Firangi-Thakurain-ep2.jpg:
#   Character tags:
#   General tags: solo, black hair, 1boy, male focus, dark skin, copyright name, facial hair, parody
#
# /content/LoRA/train_data/Firangi-Thakurain-ep22.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, large breasts, black hair, 1boy, cleavage, jewelry, swimsuit, closed eyes, bikini, sweat, bracelet, grabbing, breast grab
#
# /content/LoRA/train_data/Gadikitab2.2022.E04.jpg:
#   Character tags:
#   General tags: short hair, multiple girls, shirt, black hair, 1boy, 2girls, sitting, closed eyes, shorts, barefoot, indoors, yuri, kiss, pink shirt, realistic, very short hair
#
# /content/LoRA/train_data/Galtiyan-1.jpg:
#   Character tags:
#   General tags: 1girl, solo, blue eyes, blurry
#
# /content/LoRA/train_data/Galtiyan-12.jpg:
#   Character tags:
#   General tags: open mouth, multiple girls, black hair, 2girls, closed eyes, nude, teeth, indoors, yuri, blurry, blurry background, realistic
#
# /content/LoRA/train_data/Gandii-Baat-S07E01.jpg:
#   Character tags:
#   General tags: long hair, multiple girls, black hair, 1boy, 2girls, jewelry, swimsuit, closed eyes, hetero, bikini, earrings, lying, barefoot, yuri, bracelet, hug, on side, kiss, group sex, threesome, realistic, anklet, ffm threesome, male swimwear
#
# /content/LoRA/train_data/Gaon-Ki-Biwi-ep1.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, male focus, glasses
#
# /content/LoRA/train_data/Gaon-Ki-Biwi-ep12.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, jewelry, closed eyes, earrings, midriff, dark skin, necklace, bracelet, dark-skinned female, lips, crop top, facial mark, neck ring
#  10% 3/31 [00:07<01:06,  2.39s/it]
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep2.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, black hair, japanese clothes, lips, copyright name, piercing, portrait, nose piercing
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep22.jpg:
#   Character tags:
#   General tags: short hair, black hair, male focus, multiple boys, 2boys, looking at another, english text, blood
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep4.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, jewelry, earrings, lips, makeup, parody, cover, lipstick, realistic, nose, magazine cover, fake cover
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3-ep6.jpg:
#   Character tags:
#   General tags: 1girl, solo, jewelry, closed eyes, english text, lips, copyright name, parody, cover, realistic, fake cover
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep5.jpg:
#   Character tags:
#   General tags: 1girl, multiple girls, 2girls, jewelry, earrings, dark skin, english text, piercing, cover, black background, hoop earrings, realistic
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep7.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, dress, jewelry, upper body, blurry, english text, makeup, parody, ring, real life insert
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep72.jpg:
#   Character tags:
#   General tags: solo, 1boy, jewelry, male focus, blurry, english text, ring
#
# /content/LoRA/train_data/Gaon-Ki-Garmi-3ep8.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, brown hair, shirt, black hair, jewelry, medium breasts, upper body, midriff, necklace, lips, crop top, realistic
#
# /content/LoRA/train_data/Garmi2.2022.E01.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, open mouth, multiple girls, black hair, hair ornament, 1boy, navel, 2girls, jewelry, underwear, nipples, closed eyes, hetero, earrings, small breasts, teeth, bra, loli, facial hair, beard, white bra, realistic, breast sucking, father and daughter
#
# /content/LoRA/train_data/Ghar-Sasur-ep1-.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, large breasts, black hair, cleavage, bare shoulders, medium breasts, underwear, closed eyes, upper body, bra, sleeping, strap slip, realistic
#  13% 4/31 [00:08<00:54,  2.01s/it]
# /content/LoRA/train_data/Ghar-Sasur-ep2-.jpg:
#   Character tags:
#   General tags: short hair, black hair, 1boy, male focus, shorts, indoors, kneeling, facial hair, black shorts, beard, topless male
#
# /content/LoRA/train_data/Ghar-Sasur-ep2-2.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, black hair, 1boy, navel, underwear, panties, closed eyes, barefoot, indoors, dark skin, bra, dark-skinned female, black panties, kneeling, underwear only, black bra, female masturbation
#
# /content/LoRA/train_data/Ghar-Sasur-ep4.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, black hair, 1boy, swimsuit, hetero, bikini, solo focus, dark skin, dark-skinned female, lips, mouth hold, sex from behind, all fours, doggystyle, fake cover
#
# /content/LoRA/train_data/Ghar-Sasur-ep5.jpg:
#   Character tags:
#   General tags: 1girl, breasts, short hair, black hair, 1boy, jewelry, closed eyes, upper body, hetero, earrings, hug, grabbing, breast grab
#
# /content/LoRA/train_data/Ghar-Sasur-ep52.jpg:
#   Character tags:
#   General tags: short hair, black hair, jewelry, closed eyes, male focus, multiple boys, 2boys, hug, yaoi
#
# /content/LoRA/train_data/Ghar-Sasur-ep6.jpg:
#   Character tags:
#   General tags: 1girl, short hair, black hair, 1boy, navel, jewelry, underwear, closed eyes, hetero, pants, indoors, dark skin, necklace, bra, hug, facial hair, dark-skinned male, couple, beard, topless male, realistic, mustache
#
# /content/LoRA/train_data/Ghar-Sasur-ep62.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, underwear, closed eyes, hetero, nude, dark skin, necklace, bra, bracelet, couple, kiss, realistic
#
# /content/LoRA/train_data/Ghar-Sasur-ep7.jpg:
#   Character tags:
#   General tags: 1girl, smile, short hair, open mouth, black hair, nipples, closed eyes, hetero, nude, lying, parted lips, multiple boys, teeth, 2boys, on back, facial hair, realistic
#
# /content/LoRA/train_data/Ghar-Sasur-ep72.jpg:
#   Character tags:
#   General tags: 1girl, 1boy, hetero, penis, artist name, blurry, blurry background
#
# /content/LoRA/train_data/Ghar-Sasur-ep73.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, smile, open mouth, multiple girls, black hair, 1boy, 2girls, blue hair, closed eyes, nude, lying, parted lips, teeth, on back, yuri, realistic
#  16% 5/31 [00:08<00:46,  1.79s/it]
# /content/LoRA/train_data/Ghonchu-EP01.jpg:
#   Character tags:
#   General tags: solo, 1boy, male focus, english text, parody, realistic, logo
#
# /content/LoRA/train_data/Golu.2.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, closed eyes, lying, on back, realistic
#
# /content/LoRA/train_data/Golu.S01E01.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, brown hair, black hair, 1boy, underwear, closed eyes, hetero, lying, shorts, indoors, bra, saliva, facial hair, girl on top, black bra, realistic, saliva trail
#
# /content/LoRA/train_data/Good-Night-ep3.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, bare shoulders, jewelry, closed eyes, upper body, hetero, glasses, necklace, off shoulder, bracelet, night, couple, kiss
#
# /content/LoRA/train_data/Grand_Masti.jpg:
#   Character tags:
#   General tags: 1girl, solo, brown hair, black hair, jewelry, closed eyes, necklace, lips, portrait, realistic
#
# /content/LoRA/train_data/Grand_Masti2.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, jewelry, nipples, closed eyes, hetero, nude, small breasts, multiple boys, 2boys, necklace, facial hair, grabbing, breast grab, 3boys, group sex, beard, licking, realistic
#
# /content/LoRA/train_data/Grand_Masti3.jpg:
#   Character tags:
#   General tags: solo, 1boy, nipples, upper body, male focus, nude, dark skin, muscular, pectorals, muscular male, bara, close-up, realistic
#
# /content/LoRA/train_data/Grand_Masti4.jpg:
#   Character tags:
#   General tags: short hair, hat, nipples, male focus, nude, multiple boys, tongue, 2boys, tongue out, looking at another, muscular, facial hair, grabbing, pectorals, muscular male, bara, yaoi, beard, licking, realistic
#
# /content/LoRA/train_data/Gubare-Wali-ep1.jpg:
#   Character tags:
#   General tags: 1girl, short hair, black hair, 1boy, jewelry, closed eyes, hetero, necklace, nail polish, facial hair, grabbing, beard, realistic
#
# /content/LoRA/train_data/Gubare-Wali-ep2.jpg:
#   Character tags:
#   General tags: 1girl, breasts, short hair, open mouth, multiple girls, black hair, thighhighs, 1boy, 2girls, jewelry, underwear, lying, dark skin, on back, yuri, dark-skinned female, bed, ring, realistic, interracial, very dark skin
#  19% 6/31 [00:09<00:41,  1.64s/it]
# /content/LoRA/train_data/Guest3_Moment.jpg:
#   Character tags:
#   General tags: 1girl, short hair, shirt, black hair, 1boy, upper body, hetero, male focus, multiple boys, 2boys, from side, plaid, profile, kiss, yellow shirt, imminent kiss, plaid shirt
#
# /content/LoRA/train_data/Guest3_Moment2.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, hetero, dark skin, makeup, couple, breast press, joints, imminent kiss, real life insert
#
# /content/LoRA/train_data/Gulabo-ep3.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, black hair, 1boy, cleavage, jewelry, medium breasts, underwear, closed eyes, hetero, pants, necklace, bra, bracelet, tattoo, facial hair, couple, denim, jeans, realistic
#
# /content/LoRA/train_data/Gunha-1.jpg:
#   Character tags:
#   General tags: 1girl, short hair, brown hair, black hair, 1boy, jewelry, closed eyes, hetero, parted lips, necklace, facial hair, kiss, realistic, imminent kiss
#
# /content/LoRA/train_data/Gunha-Epi-1.jpg:
#   Character tags:
#   General tags: 1girl, solo, smile, short hair, black hair, jewelry, closed eyes, earrings, lying, parted lips, teeth, on back, bracelet, piercing, ear piercing, realistic
#
# /content/LoRA/train_data/Gupchup.2022.E04.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, tears, crying
#
# /content/LoRA/train_data/Gupchup.2022.E042.jpg:
#   Character tags:
#   General tags: 1girl, breasts, short hair, large breasts, cleavage, underwear, hetero, multiple boys, 2boys, bra, grabbing, black bra, bald, strangling
#
# /content/LoRA/train_data/Gupchup.2022.E043.jpg:
#   Character tags:
#   General tags: 1girl, short hair, black hair, 1boy, dress, jewelry, closed eyes, hetero, necklace, hug, hand on another's neck
#
# /content/LoRA/train_data/Gupchup.2022.E044.jpg:
#   Character tags:
#   General tags: 1girl, solo, short hair, black hair, nude, from behind, blurry, back
#
# /content/LoRA/train_data/GuptGyani.E02.jpg:
#   Character tags:
#   General tags: 1girl, long hair, brown hair, shirt, black hair, closed eyes, lips, realistic, tile wall, showering
#  23% 7/31 [00:10<00:37,  1.56s/it]
# /content/LoRA/train_data/Haramkhor-MooDx-Originals.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, brown hair, black hair, 1boy, navel, jewelry, medium breasts, underwear, nipples, panties, hetero, red hair, earrings, lying, dark skin, necklace, bracelet, black panties, bed, facial hair, on side, grabbing, topless, ring, breast grab, realistic, purple nails, chest hair, arm hair
#
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, navel, jewelry, medium breasts, nipples, closed eyes, hetero, nude, earrings, multiple boys, spread legs, 2boys, necklace, completely nude, group sex, hoop earrings, threesome, realistic
#
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister2.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, closed eyes, male focus, lying, indoors, on stomach, realistic
#
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister3.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, 1boy, navel, nipples, hetero, nude, small breasts, lying, multiple boys, on back, pillow, oral, curtains, group sex, threesome, realistic, cunnilingus
#
# /content/LoRA/train_data/Hardcore-Fuck-with-Step-Sister4.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, looking at viewer, smile, black hair, jewelry, medium breasts, nipples, upper body, ponytail, necklace, lips, realistic
#
# /content/LoRA/train_data/Hope-5-.jpg:
#   Character tags:
#   General tags: 1girl, long hair, shirt, black hair, 1boy, dress, blurry, facial hair, red dress, realistic
#
# /content/LoRA/train_data/Hope-5-2.jpg:
#   Character tags:
#   General tags: 1girl, solo, short hair, brown hair, shirt, white shirt, blurry
#
# /content/LoRA/train_data/Hope-5-3.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, smile, brown hair, dress, bare shoulders, brown eyes, sitting, sleeveless, red dress, realistic
#
# /content/LoRA/train_data/Hope-5-4.jpg:
#   Character tags:
#   General tags: solo, short hair, simple background, shirt, 1boy, holding, jewelry, sitting, white shirt, male focus, collared shirt, pants, grey background, cup, facial hair, ring, holding cup, beard, realistic, white pants, mustache
#
# /content/LoRA/train_data/IMG_1645678394793.jpg:
#   Character tags:
#   General tags: 1girl, solo, short hair, shirt, black hair, 1boy, jewelry, green eyes, upper body, earrings, necklace, blurry, bracelet
#  26% 8/31 [00:12<00:34,  1.51s/it]
# /content/LoRA/train_data/IMG_16456783947932.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, blurry, depth of field, meme attire
#
# /content/LoRA/train_data/IMG_1645723027396.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, brown hair, underwear, upper body, artist name, dark skin, bra, dark-skinned female, mask, parody, logo
#
# /content/LoRA/train_data/IMG_1645797588024.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, closed eyes, upper body, hetero, dark skin, couple, kiss, realistic
#
# /content/LoRA/train_data/IMG_1645798208137.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, closed eyes, hetero, lying, dark skin, bracelet, dark-skinned female, parody, kiss, realistic, very dark skin
#
# /content/LoRA/train_data/IMG_1645849263340.jpg:
#   Character tags:
#   General tags: multiple girls, 2girls, jewelry, underwear, panties, earrings, shorts, dark skin, yuri, dark-skinned female, oral, denim, denim shorts
#
# /content/LoRA/train_data/IMG_16458492633402.jpg:
#   Character tags:
#   General tags: long hair, thighhighs, 1boy, jewelry, hetero, male focus, nude, multiple boys, penis, shorts, 2boys, bracelet, facial hair, denim, yaoi, beard, realistic, chest hair
#
# /content/LoRA/train_data/IMG_16458492633403.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, multiple girls, large breasts, black hair, 1boy, jewelry, closed eyes, hetero, nude, earrings, dark skin, hug, facial hair, parody, kiss, breast sucking
#
# /content/LoRA/train_data/IMG_1645882552560.jpg:
#   Character tags:
#   General tags: 1girl, solo, jewelry, earrings, lying, parted lips, on back, realistic
#
# /content/LoRA/train_data/IMG_1646021080180.jpg:
#   Character tags:
#   General tags: black hair, 1boy, nipples, hetero, male focus, nude, multiple boys, penis, 2boys, uncensored, facial hair, oral, testicles, fellatio, yaoi, beard, handjob, what
#
# /content/LoRA/train_data/IMG_16460210801802.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, closed eyes, hetero, nude, penis, loli, uncensored, erection, oral, fellatio, realistic, 69
#  29% 9/31 [00:13<00:32,  1.46s/it]
# /content/LoRA/train_data/IMG_1646124318539.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, 1boy, nipples, ass, hetero, indoors, blurry
#
# /content/LoRA/train_data/IMG_16461243185392.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, open mouth, shirt, hat, animal ears, chibi, blurry, collar, depth of field, blurry background
#
# /content/LoRA/train_data/IMG_16461243185393.jpg:
#   Character tags:
#   General tags: 1girl, open mouth, brown hair, 1boy, closed eyes, hetero, realistic
#
# /content/LoRA/train_data/IMG_1646215780995.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, shirt, black hair, 1boy, male focus, parody
#
# /content/LoRA/train_data/IMG_1646229126545.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, black hair, 1boy, jewelry, medium breasts, nipples, closed eyes, hetero, nude, earrings, lying, dark skin, dark-skinned female, lips, kiss, realistic
#
# /content/LoRA/train_data/IMG_1646246053524.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, 1boy, cleavage, jewelry, medium breasts, underwear, closed eyes, lying, striped, bra, bracelet, parody, sleeping, lingerie, realistic, retro artstyle, spiked bracelet, red bra, afro
#
# /content/LoRA/train_data/IMG_16462460535242.jpg:
#   Character tags:
#   General tags: 1girl, solo, smile, closed mouth, closed eyes, lying, lips, animal, cat, sleeping, close-up, realistic
#
# /content/LoRA/train_data/IMG_1646283258662.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, large breasts, black hair, cleavage, jewelry, upper body, earrings, dark skin, necklace, mole, bracelet, dark-skinned female, makeup, ring, mole under mouth, covering breasts, realistic, forehead jewel
#
# /content/LoRA/train_data/IMG_1646290081317.jpg:
#   Character tags:
#   General tags: long hair, breasts, multiple girls, black hair, 2girls, closed eyes, lying, yuri, kiss
#
# /content/LoRA/train_data/IMG_1646374706287.jpg:
#   Character tags:
#   General tags: solo, black hair, 1boy, holding, weapon, male focus, blurry, english text, gun, parody
#  32% 10/31 [00:14<00:29,  1.43s/it]
# /content/LoRA/train_data/IMG_16463747062872.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, looking at viewer, smile, black hair, cleavage, medium breasts, lips, realistic
#
# /content/LoRA/train_data/IMG_1646489000436.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, closed eyes, hetero, couple, realistic
#
# /content/LoRA/train_data/IMG_1646741504585.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, large breasts, black hair, 1boy, cleavage, closed eyes, hetero, nude, lying, bed, parody, realistic
#
# /content/LoRA/train_data/IMG_1646763392422.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, jewelry, closed eyes, hetero, nude, earrings, hug, facial hair, beard, realistic, fat
#
# /content/LoRA/train_data/IMG_1646907302157.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, black hair, 1boy, medium breasts, nipples, closed eyes, hetero, nude, hug, couple, hug from behind, realistic
#
# /content/LoRA/train_data/IMG_1646914988807.jpg:
#   Character tags:
#   General tags: solo, 1boy, male focus, blurry, english text, realistic
#
# /content/LoRA/train_data/IMG_16469149888072.jpg:
#   Character tags:
#   General tags: 1girl, solo
#
# /content/LoRA/train_data/IMG_1646932135689.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, shirt, black hair, holding, jewelry, sitting, white shirt, short sleeves, earrings, indoors, t-shirt, faux traditional media
#
# /content/LoRA/train_data/IMG_16469321356892.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, 1boy, sitting, male focus, indoors, apron, fine art parody, painting (action)
#
# /content/LoRA/train_data/IMG_1647525722699.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, underwear, bra, close-up, head out of frame, blue bra
#  35% 11/31 [00:15<00:27,  1.39s/it]
# /content/LoRA/train_data/IMG_1647594336917.jpg:
#   Character tags:
#   General tags: 1girl, solo, close-up
#
# /content/LoRA/train_data/IMG_16475943369172.jpg:
#   Character tags:
#   General tags: nipples, male focus, nude, multiple boys, penis, 2boys, sex, oral, fellatio, yaoi
#
# /content/LoRA/train_data/IMG_1647595692772.jpg:
#   Character tags:
#   General tags: 1girl, solo
#
# /content/LoRA/train_data/IMG_16475956927722.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, brown hair, jewelry, pointy ears, bracelet, elf, realistic
#
# /content/LoRA/train_data/IMG_1647625632344.jpg:
#   Character tags:
#   General tags: 1girl, 1boy, jewelry, closed eyes, hetero, nude, censored, penis, solo focus, cum, bracelet, saliva, oral, fellatio
#
# /content/LoRA/train_data/IMG_16476256323442.jpg:
#   Character tags:
#   General tags: solo, 1boy, closed eyes, male focus, nude, facial hair, close-up
#
# /content/LoRA/train_data/IMG_16476256323443.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, brown hair, jewelry, nipples, closed eyes, nude, multiple boys, solo focus, necklace, tattoo, parody, what
#
# /content/LoRA/train_data/IMG_1647785582414.jpg:
#   Character tags:
#   General tags: solo, black hair, 1boy, jewelry, ass, male focus, blurry, depth of field, blurry background, ring, watch, wristwatch
#
# /content/LoRA/train_data/IMG_16477855824142.jpg:
#   Character tags:
#   General tags: 1girl, long hair, multiple girls, black hair, 1boy, closed eyes, hug, child, realistic
#
# /content/LoRA/train_data/IMG_1647867067641.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, multiple boys, 2boys, parody, realistic, fat, what, real life insert
#  39% 12/31 [00:16<00:26,  1.37s/it]
# /content/LoRA/train_data/IMG_1647969034589.jpg:
#   Character tags:
#   General tags: breasts, short hair, open mouth, black hair, underwear, panties, closed eyes, hetero, male focus, multiple boys, tears, 2boys, sex, blurry, tattoo, blurry background, facial hair, crying, sex from behind, sex toy, anal, yaoi, doggystyle, realistic, logo, strap-on
#
# /content/LoRA/train_data/IMG_1648052772770.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, brown hair, black hair, 1boy, medium breasts, underwear, nipples, panties, closed eyes, hetero, nude, dark skin, sex, makeup, breasts apart, eyeshadow, realistic, red panties
#
# /content/LoRA/train_data/IMG_1648105480903.jpg:
#   Character tags:
#   General tags: 1girl, solo, dark skin, parody
#
# /content/LoRA/train_data/IMG_1648489949518.jpg:
#   Character tags:
#   General tags: solo, 1boy, male focus, blurry
#
# /content/LoRA/train_data/IMG_16484899495182.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, black hair, jewelry, hetero, nude, earrings, multiple boys, solo focus, from side, makeup, parody, realistic
#
# /content/LoRA/train_data/IMG_16484899495183.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, hetero, male focus, nude, multiple boys, 2boys, sex, parody, cover, kiss, yaoi, realistic
#
# /content/LoRA/train_data/IMG_16484899495184.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, smile, 1boy, navel, medium breasts, nipples, blue hair, standing, hetero, nude, cowboy shot, outdoors, multiple boys, completely nude, realistic, what
#
# /content/LoRA/train_data/IMG_1648490544932.jpg:
#   Character tags:
#   General tags: black hair, 1boy, lying, blurry, bed
#
# /content/LoRA/train_data/IMG_1648531957722.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, smile, brown hair, dress, brown eyes, jewelry, earrings, bra, parody, watch, realistic, logo, wristwatch
#
# /content/LoRA/train_data/IMG_16485319577222.jpg:
#   Character tags:
#   General tags: 1girl, brown hair, 1boy, jewelry, closed eyes, hetero, bracelet, parody, couple, kiss, realistic, real life insert
#  42% 13/31 [00:17<00:24,  1.34s/it]
# /content/LoRA/train_data/IMG_1648534484819.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, jewelry, closed eyes, hetero, earrings, penis, solo focus, profile, parody, cover, handjob, hoop earrings, realistic
#
# /content/LoRA/train_data/IMG_16485344848192.jpg:
#   Character tags:
#   General tags: 1girl, solo, 1boy, holding, nail polish, fingernails, red nails, close-up
#
# /content/LoRA/train_data/IMG_1648752637291.jpg:
#   Character tags:
#   General tags: 1girl, smile, shirt, black hair, long sleeves, 1boy, holding, male focus, pants, bag, blurry, blurry background
#
# /content/LoRA/train_data/IMG_16487526372912.jpg:
#   Character tags:
#   General tags: 1girl, long hair, shirt, black hair, 1boy, jewelry, pants, blurry, bracelet, ground vehicle, realistic, riding, bicycle, multiple riders
#
# /content/LoRA/train_data/IMG_1648753077722.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, black hair, jewelry, closed mouth, dark skin, necklace, dark-skinned female, facial mark, portrait, forehead mark, realistic
#
# /content/LoRA/train_data/IMG_1648912547326.jpg:
#   Character tags:
#   General tags: solo, 1boy, hat, male focus, blurry
#
# /content/LoRA/train_data/IMG_1648921193271.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, large breasts, black hair, cleavage, jewelry, earrings, midriff, dark skin, necklace, bracelet, dark-skinned female, realistic
#
# /content/LoRA/train_data/IMG_1648923555473.jpg:
#   Character tags:
#   General tags: multiple girls, black hair, 2girls, dark skin, nail polish, yuri, blurry, tank top, green nails
#
# /content/LoRA/train_data/IMG_16489235554732.jpg:
#   Character tags:
#   General tags: 1girl, multiple girls, black hair, 1boy, 2girls, closed eyes, lying, artist name, dark skin, nail polish, yuri, facial hair, sleeping, tank top, green nails
#
# /content/LoRA/train_data/IMG_1648924942844.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, black hair, 1boy, closed mouth, upper body, profile, facial hair, animal print, realistic
#  45% 14/31 [00:18<00:22,  1.33s/it]
# /content/LoRA/train_data/IMG_16489249428442.jpg:
#   Character tags:
#   General tags: solo, short hair, shirt, black hair, 1boy, bare shoulders, closed mouth, closed eyes, white shirt, upper body, male focus, indoors, facial hair, tank top, beard, realistic, white tank top
#
# /content/LoRA/train_data/IMG_1648962796104.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, standing, indoors, blurry, window, depth of field, blurry background
#
# /content/LoRA/train_data/IMG_16489627961042.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, looking at viewer, brown hair, black hair, indoors, blurry, depth of field
#
# /content/LoRA/train_data/IMG_16489627961043.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, brown hair, brown eyes, jewelry, underwear, panties, earrings, bra, bracelet, topless, reflection, mirror, covering breasts, realistic
#
# /content/LoRA/train_data/IMG_16489627961044.jpg:
#   Character tags:
#   General tags: short hair, black hair, 1boy, jewelry, sitting, underwear, male focus, barefoot, indoors, necklace, bracelet, window, facial hair, topless male, watch, wristwatch, male underwear, boxers, boxer briefs
#
# /content/LoRA/train_data/IMG_16489627961045.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, brown hair, brown eyes, jewelry, underwear, panties, earrings, bra, bracelet, black panties, underwear only, watch, realistic, wristwatch, faux traditional media
#
# /content/LoRA/train_data/IMG_16489627961046.jpg:
#   Character tags:
#   General tags: solo, short hair, 1boy, sitting, male focus, indoors, from side, muscular, facial hair, beard, topless male, realistic, computer
#
# /content/LoRA/train_data/IMG_1649005793187.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, 1boy, dress, jewelry, bracelet, hug, ring, watch
#
# /content/LoRA/train_data/IMG_16490057931872.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, dress, jewelry, hetero, bracelet, parody, red dress, kiss
#
# /content/LoRA/train_data/IMG_1649055910834.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, closed eyes, facial hair, sleeping, realistic
#  48% 15/31 [00:19<00:20,  1.30s/it]
# /content/LoRA/train_data/IMG_1649179338859.jpg:
#   Character tags:
#   General tags: breasts, multiple girls, black hair, 2girls, cleavage, jewelry, closed eyes, hetero, earrings, dark skin, yuri, bracelet, dark-skinned female, kiss, french kiss
#
# /content/LoRA/train_data/IMG_1649358443843.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, short hair, 1boy, cleavage, jewelry, monochrome, upper body, greyscale, necklace, spot color
#
# /content/LoRA/train_data/IMG_1649644466657.jpg:
#   Character tags:
#   General tags: 1girl, breasts, open mouth, large breasts, black hair, 1boy, underwear, closed eyes, hetero, bra, lingerie, realistic
#
# /content/LoRA/train_data/IMG_16496444666572.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, open mouth, large breasts, black hair, jewelry, underwear, closed eyes, earrings, lying, on back, bra
#
# /content/LoRA/train_data/IMG_1649730093179.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, blurry
#
# /content/LoRA/train_data/IMG_16497300931792.jpg:
#   Character tags:
#   General tags: 1girl, solo, short hair, skirt, black hair, holding, indoors, blurry
#
# /content/LoRA/train_data/IMG_16497300931793.jpg:
#   Character tags:
#   General tags: solo, short hair, shirt, black hair, 1boy, male focus, indoors, from behind, blurry, facial hair, towel, topless male
#
# /content/LoRA/train_data/IMG_16497300931794.jpg:
#   Character tags:
#   General tags: short hair, black hair, 1boy, standing, male focus, multiple boys, shorts, striped, indoors, 2boys, blurry, blurry background, reflection, meme, topless male, mirror
#
# /content/LoRA/train_data/IMG_1649816492417.jpg:
#   Character tags:
#   General tags: 1girl, short hair, multiple girls, black hair, 1boy, 2girls, jewelry, underwear, panties, closed eyes, hetero, lying, shorts, pants, on back, yuri, white panties, bracelet, hug, clothes pull, topless, ring, couple, denim, kiss, denim shorts, jeans, realistic
#
# /content/LoRA/train_data/IMG_1649841886166.jpg:
#   Character tags:
#   General tags: short hair, black hair, 1boy, nipples, closed eyes, male focus, nude, multiple boys, 2boys, muscular, facial hair, grabbing, pectorals, muscular male, bara, yaoi, beard, large pectorals, watch, mature male, realistic, wristwatch, pectoral grab
#  52% 16/31 [00:20<00:19,  1.28s/it]
# /content/LoRA/train_data/IMG_1649963022108.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, closed mouth, closed eyes, earrings, dark skin, parody, dark-skinned male, meme, hoop earrings, realistic, bald
#
# /content/LoRA/train_data/IMG_1650038990330.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, 1boy, jewelry, medium breasts, nipples, hetero, nude, earrings, lying, tongue, on back, tattoo, grabbing, dark-skinned male, breast grab, licking, realistic, licking nipple
#
# /content/LoRA/train_data/IMG_1650074240285.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, 1boy, jewelry, closed eyes, hetero, nude, sex, bracelet, facial hair, kiss, realistic
#
# /content/LoRA/train_data/IMG_1650074657811.jpg:
#   Character tags:
#   General tags: 1girl, open mouth, black hair, 1boy, jewelry, closed eyes, earrings, dark skin, border, freckles, very short hair, old, wrinkled skin
#
# /content/LoRA/train_data/IMG_16500746578112.jpg:
#   Character tags:
#   General tags: 1boy, male focus, looking at another, colored skin, freckles, meme, bald, very short hair
#
# /content/LoRA/train_data/IMG_1650075459688.jpg:
#   Character tags:
#   General tags: 1girl, long hair, simple background, black hair, 1boy, jewelry, closed eyes, upper body, white hair, hetero, nude, earrings, mole, facial hair, couple, kiss, beard, imminent kiss
#
# /content/LoRA/train_data/IMG_16500754596882.jpg:
#   Character tags:
#   General tags: long hair, multiple girls, black hair, 2girls, closed eyes, yuri, mole, kiss
#
# /content/LoRA/train_data/IMG_1650078871392.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, brown hair, 1boy, 2girls, cleavage, closed eyes, lying, on back, yuri, oral, realistic, cunnilingus
#
# /content/LoRA/train_data/IMG_16500788713922.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, 1boy, underwear, nipples, hetero, realistic
#
# /content/LoRA/train_data/IMG_1650330618284.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, 1boy, bare shoulders, closed eyes, facial mark, forehead mark, realistic
#  55% 17/31 [00:21<00:17,  1.26s/it]
# /content/LoRA/train_data/IMG_16503306182842.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, closed eyes, male focus, multiple boys, parody, ring, realistic, fine art parody
#
# /content/LoRA/train_data/IMG_1650331276485.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, brown hair, black hair, 1boy, cleavage, jewelry, closed eyes, hetero, earrings, lying, dark skin, necklace, bracelet, bed, ring, couple, girl on top, mature female, realistic, wedding ring
#
# /content/LoRA/train_data/IMG_1650558830731.jpg:
#   Character tags:
#   General tags: 1girl, open mouth, brown hair, black hair, 1boy, closed eyes, hetero, nude, lying, indoors, sex, on back, bed, missionary, realistic, boy on top, what, fine art parody
#
# /content/LoRA/train_data/IMG_1650642170805.jpg:
#   Character tags:
#   General tags: 1girl, black hair, jewelry, closed eyes, male focus, earrings, multiple boys, 2boys, muscular, facial hair, bara, yaoi, beard, realistic, chest hair
#
# /content/LoRA/train_data/IMG_1650736011315.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, hetero, male focus, multiple boys, 2boys, facial hair, kiss, yaoi, beard, realistic, hand on another's neck
#
# /content/LoRA/train_data/IMG_1650791074824.jpg:
#   Character tags:
#   General tags: 1girl, short hair, black hair, 1boy, nipples, closed eyes, male focus, nude, lying, multiple boys, indoors, 2boys, on back, realistic, hand on another's chest, fine art parody
#
# /content/LoRA/train_data/IMG_1650965196175.jpg:
#   Character tags:
#   General tags: 1girl, solo, 1boy, male focus, blurry, realistic
#
# /content/LoRA/train_data/IMG_16509651961752.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, 1boy, male focus, artist name, blurry
#
# /content/LoRA/train_data/IMG_16509651961753.jpg:
#   Character tags:
#   General tags: solo, black hair, 1boy, male focus, nude, indoors, from behind, book, bookshelf
#
# /content/LoRA/train_data/IMG_1651169148935.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, open mouth, brown hair, shirt, 1boy, closed eyes, blurry, blurry background, meme
#  58% 18/31 [00:22<00:16,  1.24s/it]
# /content/LoRA/train_data/IMG_16511691489352.jpg:
#   Character tags:
#   General tags: solo, short hair, black hair, 1boy, closed mouth, upper body, male focus, indoors, blurry, muscular, blurry background, facial hair, pectorals, muscular male, bara, beard, large pectorals, meme, topless male, mature male
#
# /content/LoRA/train_data/IMG_1651174228352.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, bare shoulders, jewelry, closed eyes, midriff, artist name, indoors, dark skin, necklace, blurry, bracelet, dark-skinned female, crop top, makeup, reflection, mirror, realistic
#
# /content/LoRA/train_data/IMG_1651174876374.jpg:
#   Character tags:
#   General tags: multiple girls, black hair, 2girls, jewelry, closed eyes, earrings, tongue, necklace, yuri, kiss, close-up, realistic, french kiss
#
# /content/LoRA/train_data/IMG_16511748763742.jpg:
#   Character tags:
#   General tags: multiple girls, black hair, 2girls, jewelry, closed eyes, earrings, necklace, yuri, blurry, couple, kiss, realistic, french kiss
#
# /content/LoRA/train_data/IMG_1651250163788.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, black hair, 1boy, jewelry, underwear, nipples, closed eyes, hetero, barefoot, bracelet, plaid, ring, realistic, male underwear, boxers
#
# /content/LoRA/train_data/IMG_16512501637882.jpg:
#   Character tags:
#   General tags: 1girl, breasts, large breasts, black hair, 1boy, jewelry, underwear, nipples, closed eyes, hetero, lying, dark skin, bra, bracelet, pillow, bed, ring, sleeping, breasts apart, realistic
#
# /content/LoRA/train_data/IMG_1651298588976.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, underwear, panties, ass, hetero, earrings, dark skin, nail polish, bra, lingerie, pink panties, lace, ass grab, realistic
#
# /content/LoRA/train_data/IMG_1651429214970.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, 1boy, closed eyes, hetero, nude, teeth, dark skin, dark-skinned female, realistic
#
# /content/LoRA/train_data/IMG_1651517635956.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, short hair, black hair, 1boy, upper body, male focus, nude, blurry, depth of field, blurry background, colored skin
#
# /content/LoRA/train_data/IMG_16515176359562.jpg:
#   Character tags:
#   General tags: 1girl, solo, short hair, shirt, hat, blurry, depth of field
#  61% 19/31 [00:23<00:14,  1.22s/it]
# /content/LoRA/train_data/IMG_16515176359563.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, 1boy, upper body, nude, blurry, blurry background, colored skin
#
# /content/LoRA/train_data/IMG_1651520075087.jpg:
#   Character tags:
#   General tags: brown hair, 1boy, jewelry, male focus, bracelet, english text, facial hair, parody, cover, beard, fake cover
#
# /content/LoRA/train_data/IMG_16515200750872.jpg:
#   Character tags:
#   General tags: 1girl, long hair, brown hair, shirt, black hair, 1boy, jewelry, sitting, artist name, necklace, bracelet, profile, facial hair, parody, realistic
#
# /content/LoRA/train_data/IMG_1651612524734.jpg:
#   Character tags:
#   General tags: short hair, black hair, ass, male focus, nude, lying, multiple boys, 2boys, completely nude, bed, muscular, facial hair, on bed, muscular male, bara, yaoi, beard, realistic, chest hair, leg hair, fine art parody
#
# /content/LoRA/train_data/IMG_1651762340451.jpg:
#   Character tags:
#   General tags: 1girl, long hair, brown hair, shirt, black hair, 1boy, brown eyes, jewelry, closed eyes, hetero, earrings, dark skin, bracelet, plaid, hug, facial hair, parody, grabbing, ring, breast grab, beard, meme, watch, hug from behind, realistic, wristwatch, plaid shirt
#
# /content/LoRA/train_data/IMG_1651762920582.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, brown hair, black hair, 1boy, cleavage, jewelry, medium breasts, underwear, closed eyes, hetero, earrings, shorts, indoors, bra, window, facial hair, grabbing, breast grab, black bra, plump, realistic, grabbing from behind, pink shorts
#
# /content/LoRA/train_data/IMG_1651777279287.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, black hair, 1boy, jewelry, male focus, earrings, armor, parody, forehead mark, realistic
#
# /content/LoRA/train_data/IMG_1651854073336.jpg:
#   Character tags:
#   General tags: 1girl, 1boy, dress, jewelry, hetero, necklace, holding hands, parody, straddling, girl on top, interlocked fingers, cowgirl position, green skin, painting (object)
#
# /content/LoRA/train_data/IMG_16518540733362.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, cleavage, jewelry, underwear, collarbone, closed eyes, upper body, earrings, parted lips, bra
#
# /content/LoRA/train_data/IMG_1651984085031.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, brown hair, black hair, dress, jewelry, medium breasts, earrings, parted lips, necklace, nail polish, bracelet, english text, lips, makeup, parody, lipstick
#  65% 20/31 [00:24<00:13,  1.20s/it]
# /content/LoRA/train_data/IMG_1651986981717.jpg:
#   Character tags:
#   General tags: 1girl, open mouth, black hair, 1boy, dress, jewelry, closed eyes, hetero, horns, parody, ring, watch, realistic, wristwatch
#
# /content/LoRA/train_data/IMG_1652029917654.jpg:
#   Character tags:
#   General tags: 1girl, solo, blurry, depth of field, blurry background
#
# /content/LoRA/train_data/IMG_16520299176542.jpg:
#   Character tags:
#   General tags: 1girl, long hair, smile, shirt, black hair, long sleeves, solo focus, striped, striped shirt, realistic
#
# /content/LoRA/train_data/IMG_16520299176543.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, closed mouth, closed eyes, upper body, blurry, realistic
#
# /content/LoRA/train_data/IMG_16520299176544.jpg:
#   Character tags:
#   General tags: short hair, multiple girls, brown hair, black hair, 2girls, closed eyes, dark skin, yuri, kiss, realistic
#
# /content/LoRA/train_data/IMG_16520299176545.jpg:
#   Character tags:
#   General tags: 1girl, smile, shirt, black hair, 1boy, hetero, male focus, striped, artist name, nail polish, meme, ass grab, striped shirt
#
# /content/LoRA/train_data/IMG_1652032127110.jpg:
#   Character tags:
#   General tags: 1girl, breasts, 1boy, medium breasts, nipples, closed eyes, hetero, nude, earrings, small breasts, lying, solo focus, sex, bed, grabbing, breast grab, realistic
#
# /content/LoRA/train_data/IMG_1652098098040.jpg:
#   Character tags:
#   General tags: black hair, thighhighs, 1boy, ass, male focus, multiple boys, dark skin, 2boys, facial hair, garter straps, bandages, yaoi, beard, meme, ass grab, bandaged arm, logo, bald
#
# /content/LoRA/train_data/IMG_1652376596091.jpg:
#   Character tags:
#   General tags: 1girl, breasts, brown hair, 1boy, medium breasts, nipples, closed eyes, hetero, nude, lying, on back, realistic
#
# /content/LoRA/train_data/IMG_16523765960912.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, 1boy, closed eyes, hetero, tongue, dark skin, kiss
#  68% 21/31 [00:25<00:11,  1.19s/it]
# /content/LoRA/train_data/IMG_1652383393155.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, upper body, male focus, from side, profile, facial hair, realistic, labcoat, bald, very short hair, stethoscope, doctor
#
# /content/LoRA/train_data/IMG_16523833931552.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, teeth, own hands together, realistic, own hands clasped
#
# /content/LoRA/train_data/IMG_1652455805656.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, skirt, blonde hair, shirt, hat, bow, blurry
#
# /content/LoRA/train_data/IMG_16524558056562.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, male focus, japanese clothes, multiple boys, blurry
#
# /content/LoRA/train_data/IMG_16524558056563.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, hetero, blurry, depth of field, kiss, bookshelf
#
# /content/LoRA/train_data/IMG_1653199888630.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, upper body, male focus, blurry, depth of field, border
#
# /content/LoRA/train_data/IMG_16531998886302.jpg:
#   Character tags:
#   General tags: 1girl, solo, skirt, shirt, black hair, long sleeves, indoors, blurry, depth of field, blurry background, pink shirt
#
# /content/LoRA/train_data/IMG_1653880199441.jpg:
#   Character tags:
#   General tags: 1girl, long hair, black hair, 1boy, dress, jewelry, closed eyes, hetero, facial hair, couple, kiss, beard, realistic
#
# /content/LoRA/train_data/IMG_16538801994412.jpg:
#   Character tags:
#   General tags: 1girl, shirt, black hair, 1boy, jewelry, sitting, hetero, male focus, necktie, blurry, bracelet, facial hair, kiss, yaoi, beard
#
# ...
#   Character tags:
#   General tags: 1girl, solo, long hair, smile, shirt, black hair, jewelry, teeth, dark skin, necklace, grin, bracelet, english text, dark-skinned female, parody, ring, red shirt
#
# /content/LoRA/train_data/dream-girl-ep6.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, brown hair, brown eyes, upper body, from side, lips, profile, nose
#  74% 23/31 [00:26<00:09,  1.17s/it]
# /content/LoRA/train_data/dream-girl-ep62.jpg:
#   Character tags:
#   General tags: shirt, black hair, 1boy, upper body, male focus, from side, english text, copyright name, facial hair, parody, beard, animification
#
# /content/LoRA/train_data/duhan-e01.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, dress, closed eyes, hetero, lying, parted lips, on back, purple dress, realistic
#
# /content/LoRA/train_data/e4.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, dress, brown eyes, jewelry, necklace, scarf, nail polish, bracelet, realistic
#
# /content/LoRA/train_data/e42.jpg:
#   Character tags:
#   General tags: solo, short hair, shirt, black hair, 1boy, jewelry, upper body, male focus, outdoors, blurry, bracelet, from side, blurry background, facial hair, beard, sideburns, very short hair
#
# /content/LoRA/train_data/e43.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, short sleeves, male focus, glasses, collared shirt, belt, facial hair, blue shirt, beard, realistic, logo, photo background
#
# /content/LoRA/train_data/ee9.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, male focus, glasses, pants, facial hair, watch, wristwatch
#
# /content/LoRA/train_data/ee92.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, short hair, simple background, brown hair, shirt, 1boy, jewelry, closed mouth, upper body, earrings, lips, black shirt, watch, realistic, wristwatch, reference inset
#
# /content/LoRA/train_data/ek-ajnabee-ep2.jpg:
#   Character tags:
#   General tags: 1girl, breasts, brown hair, black hair, 1boy, medium breasts, closed eyes, hetero, nude, lying, on back, completely nude, facial hair, grabbing, realistic
#
# /content/LoRA/train_data/ek-sath-teen-teen-ep1.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, hetero, nude, lying, food, sketch, loli, oral, ring, cunnilingus, 69
#
# /content/LoRA/train_data/ek-sath-teen-teen-ep12.jpg:
#   Character tags:
#   General tags: breasts, multiple girls, black hair, 2girls, cleavage, jewelry, medium breasts, underwear, panties, closed eyes, lying, indoors, bra, yuri, bed, makeup, on bed, oral, ring, on stomach, realistic, bedroom, cunnilingus
#  77% 24/31 [00:27<00:08,  1.16s/it]
# /content/LoRA/train_data/ek-sath-teen-teen-ep2.jpg:
#   Character tags:
#   General tags: 1girl, solo, open mouth, black hair, dress, jewelry, earrings, dark skin, necklace, dark-skinned female, looking up, realistic
#
# /content/LoRA/train_data/ep22.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, black hair, medium breasts, nipples, closed eyes, upper body, nude, small breasts, lips, realistic
#
# /content/LoRA/train_data/ep222.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, black hair, 1boy, medium breasts, nipples, closed eyes, hetero, nude, small breasts, mole, lips, hug from behind, realistic
#
# /content/LoRA/train_data/ep3-1.jpg:
#   Character tags:
#   General tags: 1boy, male focus, blurry, depth of field, blurry background, cover
#
# /content/LoRA/train_data/ep3.jpg:
#   Character tags:
#   General tags: solo, looking at viewer, brown hair, 1boy, closed mouth, male focus, facial hair, portrait, mustache
#
# /content/LoRA/train_data/ep32.jpg:
#   Character tags:
#   General tags: 1girl, solo, looking at viewer, brown hair, nude, parted lips, looking back, english text, realistic
#
# /content/LoRA/train_data/epp1.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, blonde hair, brown hair, holding, cleavage, jewelry, medium breasts, midriff, necklace, bracelet, lips, crop top, phone, ring, cellphone, tank top, smartphone, holding phone, realistic, looking at phone, blue tank top
#
# /content/LoRA/train_data/favoriteteacherep-04-mkv-20220211-072046-587.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, breasts, blue eyes, black hair, cleavage, jewelry, medium breasts, underwear, parted lips, indoors, bra, bracelet, phone, cellphone, denim, jeans, realistic, red bra
#
# /content/LoRA/train_data/flat-screen-ep1.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, closed eyes, hetero, nude, penis, solo focus, oral, fellatio, realistic
#
# /content/LoRA/train_data/flat-screen-ep12.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, nipples, closed eyes, male focus, nude, earrings, indoors, parody, realistic, lamp, bald
#  81% 25/31 [00:28<00:06,  1.15s/it]
# /content/LoRA/train_data/flat-screen-ep2.jpg:
#   Character tags:
#   General tags: multiple girls, 1boy, 2girls, closed eyes, dark skin, yuri, dark-skinned female, head out of frame
#
# /content/LoRA/train_data/flat-screen-ep22.jpg:
#   Character tags:
#   General tags: 1girl, short hair, 1boy, sitting, closed eyes, male focus, multiple boys, pants, indoors, dark skin, dark-skinned male, kiss, topless male, realistic, bald
#
# /content/LoRA/train_data/fragrance.jpg:
#   Character tags:
#   General tags: short hair, shirt, black hair, 1boy, hat, jewelry, closed eyes, upper body, short sleeves, male focus, multiple boys, 2boys, bracelet, yaoi, pink shirt, realistic, arm hair
#
# /content/LoRA/train_data/fragrance2.jpg:
#   Character tags:
#   General tags: 1girl, breasts, black hair, gloves, 1boy, jewelry, nipples, closed eyes, hetero, choker, elbow gloves, bracelet, realistic
#
# /content/LoRA/train_data/fuljhadi-bhabhi-ep1.jpg:
#   Character tags:
#   General tags: 1girl, solo, shirt, 1boy, white shirt, male focus, pants, tank top
#
# /content/LoRA/train_data/fuljhadi-bhabhi-ep12.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, shirt, upper body, blurry, motion blur
#
# /content/LoRA/train_data/gachi4.jpg:
#   Character tags:
#   General tags: solo, brown hair, shirt, black hair, 1boy, jewelry, male focus, earrings, dark skin, necklace, dark-skinned male, realistic
#
# /content/LoRA/train_data/gachi42.jpg:
#   Character tags:
#   General tags: short hair, shirt, black hair, jewelry, upper body, male focus, multiple boys, artist name, 2boys, bracelet, facial hair, ring, yaoi, beard
#
# /content/LoRA/train_data/gachi5.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, jewelry, closed mouth, earrings, artist name, necklace, hair bun, from side, profile, single hair bun, realistic
#
# /content/LoRA/train_data/gachi52.jpg:
#   Character tags:
#   General tags: 1girl, solo, brown hair, jewelry, closed eyes, hair bun, facial mark, parody, piercing, forehead mark
#  84% 26/31 [00:29<00:05,  1.14s/it]
# /content/LoRA/train_data/gachi6.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, brown hair, brown eyes, jewelry, earrings, artist name, necklace, blurry, lips, blurry background, parody, realistic
#
# /content/LoRA/train_data/gandi-baat-ep2.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, male focus, lying, on back, necklace, looking at another, realistic, fine art parody
#
# /content/LoRA/train_data/gao-ki-malai-ep2.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, jewelry, underwear, closed eyes, hetero, lying, nail polish, mole, bracelet, pillow, petals, hug, bed, facial hair, topless, ring, couple, topless male, realistic, wedding ring, fat, rose petals, husband and wife
#
# /content/LoRA/train_data/garmi-ep-3.jpg:
#   Character tags:
#   General tags: shirt, black hair, 1boy, jewelry, male focus, multiple boys, 2boys, black shirt, facial hair, ring, t-shirt, yaoi, watch, wristwatch
#
# /content/LoRA/train_data/garmi-ep-32.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, navel, underwear, panties, hetero, black panties, watch, realistic
#
# /content/LoRA/train_data/ghar-ka-call-boy-ep4.jpg:
#   Character tags:
#   General tags: 1girl, multiple girls, black hair, 1boy, underwear, ass, hetero, kiss, ass grab
#
# /content/LoRA/train_data/ghar-ka-call-boy-ep42.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, jewelry, swimsuit, bikini, parody, ball, realistic
#
# /content/LoRA/train_data/ghar-ka-call-boy-ep6.jpg:
#   Character tags:
#   General tags: 1girl, short hair, black hair, 1boy, jewelry, hetero, dark skin, sex, english text, dark-skinned female, ring, legs up, watch, wristwatch
#
# /content/LoRA/train_data/ghar-ka-call-boy-ep62.jpg:
#   Character tags:
#   General tags: 1girl, multiple girls, black hair, 2girls, jewelry, closed eyes, yuri, blurry, bracelet, ring, watch, realistic, wristwatch
#
# /content/LoRA/train_data/gidgboz2.jpg:
#   Character tags:
#   General tags: 1girl, solo, brown hair, black hair, jewelry, closed eyes, earrings, lips, realistic
#  87% 27/31 [00:30<00:04,  1.14s/it]
# /content/LoRA/train_data/gidgboz22.jpg:
#   Character tags:
#   General tags: 1girl, solo, black hair, 1boy, jewelry, weapon, male focus, earrings, bag, afro
#
# /content/LoRA/train_data/good-luck-ep4.jpg:
#   Character tags:
#   General tags: short hair, open mouth, black hair, holding, closed eyes, male focus, multiple boys, solo focus, pants, 2boys, muscular, facial hair, black pants, pectorals, muscular male, yaoi, beard, topless male, realistic, mustache, chest hair, arm hair
#
# /content/LoRA/train_data/good-luck-ep42.jpg:
#   Character tags:
#   General tags: 1girl, breasts, short hair, open mouth, black hair, 1boy, navel, underwear, closed eyes, hetero, shorts, armpits, bra, arms up, short shorts, facial hair, grabbing, black shorts, breast grab, denim, beard, licking, white bra, denim shorts, groping, grabbing from behind, arm hair
#
# /content/LoRA/train_data/gulabo-e02.jpg:
#   Character tags:
#   General tags: 1girl, solo, skirt, hat, standing, blurry, depth of field, blurry background
#
# /content/LoRA/train_data/gulabo-e022.jpg:
#   Character tags: kemomimi-chan (naga u)
#   General tags: 1girl, solo, skirt, blonde hair, shirt, hair ornament, thighhighs, long sleeves, animal ears, tail, pleated skirt, sailor collar, hair bun, blurry, collar, white thighhighs, animal ear fluff, sleeves past wrists, fox ears, bell, depth of field, blurry background, fox tail, animal, fox girl, jingle bell, neck bell, sleeves past fingers, purple skirt, white sailor collar, green shirt, zouri
#
# /content/LoRA/train_data/gulabo-e023.jpg:
#   Character tags:
#   General tags: 1girl, solo, breasts, open mouth, large breasts, dress, cleavage, jewelry, sitting, closed eyes, necklace, bracelet, realistic
#
# /content/LoRA/train_data/gulabo-e024.jpg:
#   Character tags:
#   General tags: shirt, black hair, 1boy, jewelry, white shirt, male focus, penis, pants, dark skin, necklace, oral, dark-skinned male, ring, fellatio, t-shirt
#
# /content/LoRA/train_data/guptrog-ep2.jpg:
#   Character tags:
#   General tags: 1girl, long hair, looking at viewer, brown hair, shirt, black hair, 1boy, brown eyes, hetero, shorts, teeth, midriff, striped, crop top, short shorts, facial hair, denim, beard, denim shorts, jeans, striped shirt, realistic
#
# /content/LoRA/train_data/halala-ep1.jpg:
#   Character tags:
#   General tags: 1girl, long hair, breasts, black hair, 1boy, jewelry, underwear, panties, closed eyes, hetero, earrings, lying, indoors, dark skin, on back, bra, bracelet, facial hair, realistic, pink bra, purple bra, boy on top, hand on another's neck
#
# /content/LoRA/train_data/halala-ep12.jpg:
#   Character tags:
#   General tags: 1girl, solo, blurry
#  90% 28/31 [00:31<00:03,  1.14s/it]
# /content/LoRA/train_data/hamari-sapna-bhabhi-ep3.jpg:
#   Character tags:
#   General tags: 1girl, 1boy, dress, jewelry, closed eyes, hetero, earrings, lying, parted lips, bracelet, makeup, red dress, lipstick, girl on top, red lips, forehead jewel
#
# /content/LoRA/train_data/hanymoon-2.jpg:
#   Character tags:
#   General tags: 1girl, black hair, 1boy, hetero, male focus, multiple boys, 2boys, facial hair, couple, yaoi, beard
#
# /content/LoRA/train_data/hanymoon-22.jpg:
#   Character tags:
#   General tags: 1girl, brown hair, black hair, 1boy, jewelry, closed eyes, hetero, earrings, facial hair, beard, realistic
#
# /content/LoRA/train_data/hast-Maithoon-ep2.jpg:
#   Character tags:
#   General tags: 1girl, smile, black hair, 1boy, jewelry, hetero, nude, nail polish, grin, bracelet, facial hair, ring, watch, realistic, wristwatch
#
# /content/LoRA/train_data/hast-Maithoon-ep22.jpg:
#   Character tags:
#   General tags:
#
# /content/LoRA/train_data/hast-Maithoon-ep23.jpg:
#   Character tags:
#   General tags: 1girl, smile, black hair, 1boy, jewelry, closed eyes, hetero, male focus, nude, multiple boys, 2boys, sex, bracelet, facial hair, ring, anal, yaoi, beard, watch, realistic, wristwatch
#
# /content/LoRA/train_data/hawash-ep1.jpg:
#   Character tags:
#   General tags: 1girl, open mouth, black hair, 1boy, jewelry, closed eyes, hetero, nude, artist name, sex, bracelet, bed, on bed, age difference, realistic, bald, breast sucking, old, old man
#
# /content/LoRA/train_data/hb5v1a3uojcf.jpg:
#   Character tags:
#   General tags: 1girl, solo, blurry
#
# /content/LoRA/train_data/hgds.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, sitting, male focus, heart, glasses, pants, indoors, facial hair, robot, t-shirt, beard, fat, fat man, what, glitch
#
# /content/LoRA/train_data/hgds2.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, dress, jewelry, sitting, necklace, bracelet, own hands together, pink dress, realistic, hands on lap
#  94% 29/31 [00:33<00:02,  1.14s/it]
# /content/LoRA/train_data/hh4.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, black hair, brown eyes, jewelry, upper body, braid, earrings, lips, single braid, copyright name, facial mark, forehead mark, realistic, retro artstyle
#
# /content/LoRA/train_data/hh5.jpg:
#   Character tags:
#   General tags: 1girl, solo, jewelry, dark skin, bracelet, no humans, stuffed toy, stuffed animal, teddy bear
#
# /content/LoRA/train_data/hh52.jpg:
#   Character tags:
#   General tags: solo, short hair, shirt, black hair, 1boy, jewelry, sitting, short sleeves, male focus, earrings, pants, from behind, blue shirt
#
# /content/LoRA/train_data/hh53.jpg:
#   Character tags:
#   General tags: solo, shirt, black hair, 1boy, jewelry, male focus, bracelet, facial hair, parody, beard, afro
#
# /content/LoRA/train_data/honey-trap-ep1.jpg:
#   Character tags:
#   General tags: 1girl, long hair, smile, shirt, black hair, 1boy, dress, closed eyes, teeth, striped, blue dress, parody, meme
#
# /content/LoRA/train_data/hope-ep1.jpg:
#   Character tags:
#   General tags: 1girl, short hair, shirt, black hair, 1boy, jewelry, underwear, closed eyes, hetero, lying, pants, dark skin, on back, bracelet, facial hair, grabbing, dark-skinned male, breast grab, tank top, couple, denim, kiss, beard, jeans, interracial, groping, orange shirt, hand under clothes
#
# /content/LoRA/train_data/hope-ep2.jpg:
#   Character tags:
#   General tags: 1girl, solo, gloves, 1boy, male focus, indoors, fingerless gloves, blurry
#
# /content/LoRA/train_data/hope-ep22.jpg:
#   Character tags:
#   General tags: 1girl, breasts, shirt, 1boy, hetero, bed, grabbing, breast grab, what
#
# /content/LoRA/train_data/hope-ep4.jpg:
#   Character tags:
#   General tags: short hair, black hair, navel, closed eyes, male focus, nude, multiple boys, artist name, 2boys, water, watermark, traditional media, couple, yaoi, partially submerged, male underwear, hand on another's neck
#
# /content/LoRA/train_data/iloveyouep1.jpg:
#   Character tags:
#   General tags: 1girl, solo, long hair, open mouth, black hair, closed eyes, glasses, lips, parody, black-framed eyewear, realistic
# 100% 31/31 [00:34<00:00,  1.10s/it]
#
# /content/LoRA/train_data/iloveyouep2.jpg:
#   Character tags:
#   General tags: solo, black hair, 1boy, upper body, male focus, from behind, english text, afro
#
# /content/LoRA/train_data/iloveyouep22.jpg:
#   Character tags:
#   General tags: 1girl, solo, from behind
# done!

# %%
# @title ### 4.2.3. Custom Caption/Tag
import os

# %store -r

os.chdir(root_dir)

# @markdown Add or remove custom tags here. You can refer to this [cheatsheet](https://rentry.org/kohyaminiguide#c-custom-tagscaption) for more information.
extension = ".txt"  # @param [".txt", ".caption"]
custom_tag = "indian"  # @param {type:"string"}
# @markdown Use `sub_folder` option to specify a subfolder for multi-concept training.
# @markdown > Specify `--all` to process all subfolders/`recursive`
sub_folder = "" #@param {type: "string"}
# @markdown Enable this to append custom tags at the end of lines.
append = True  # @param {type:"boolean"}
# @markdown Enable this if you want to remove captions/tags instead.
remove_tag = False  # @param {type:"boolean"}
recursive = False

if sub_folder == "":
    image_dir = train_data_dir
elif sub_folder == "--all":
    image_dir = train_data_dir
    recursive = True
elif sub_folder.startswith("/content"):
    image_dir = sub_folder
else:
    image_dir = os.path.join(train_data_dir, sub_folder)
    os.makedirs(image_dir, exist_ok=True)

def read_file(filename):
    with open(filename, "r") as f:
        contents = f.read()
    return contents

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

def process_tags(filename, custom_tag, append, remove_tag):
    contents = read_file(filename)
    tags = [tag.strip() for tag in contents.split(',')]
    custom_tags = [tag.strip() for tag in custom_tag.split(',')]

    for custom_tag in custom_tags:
        custom_tag = custom_tag.replace("_", " ")
        if remove_tag:
            while custom_tag in tags:
                tags.remove(custom_tag)
        else:
            if custom_tag not in tags:
                if append:
                    tags.append(custom_tag)
                else:
                    tags.insert(0, custom_tag)

    contents = ', '.join(tags)
    write_file(filename, contents)

def process_directory(image_dir, tag, append, remove_tag, recursive):
    for filename in os.listdir(image_dir):
        file_path = os.path.join(image_dir, filename)

        if os.path.isdir(file_path) and recursive:
            process_directory(file_path, tag, append, remove_tag, recursive)
        elif filename.endswith(extension):
            process_tags(file_path, tag, append, remove_tag)

tag = custom_tag

if not any(
    [filename.endswith(extension) for filename in os.listdir(image_dir)]
):
    for filename in os.listdir(image_dir):
        if filename.endswith((".png", ".jpg", ".jpeg", ".webp", ".bmp")):
            open(
                os.path.join(image_dir, filename.split(".")[0] + extension),
                "w",
            ).close()

if custom_tag:
    process_directory(image_dir, tag, append, remove_tag, recursive)

# %% [markdown]
# # V. Training Model

# %%
# @title ## 5.1. Model Config
from google.colab import drive

v2 = False  # @param {type:"boolean"}
v_parameterization = False  # @param {type:"boolean"}
project_name = "idklora2"  # @param {type:"string"}
if not project_name:
    project_name = "last"
# %store project_name
pretrained_model_name_or_path = "/content/pretrained_model/realisticVisionV20_v20.safetensors"  # @param {type:"string"}
vae = ""  # @param {type:"string"}
output_dir = "/content/LoRA/output"  # @param {'type':'string'}

# @markdown `output_to_drive` sets default `output_dir` to `/content/drive/MyDrive/LoRA/output`. This will override the `output_dir` variable defined above.
output_to_drive = False  # @param {'type':'boolean'}

if output_to_drive:
    output_dir = "/content/drive/MyDrive/LoRA/output"

    if not os.path.exists("/content/drive"):
        drive.mount("/content/drive")

sample_dir = os.path.join(output_dir, "sample")
for dir in [output_dir, sample_dir]:
    os.makedirs(dir, exist_ok=True)

print("Project Name: ", project_name)
print("Model Version: Stable Diffusion V1.x") if not v2 else ""
print("Model Version: Stable Diffusion V2.x") if v2 and not v_parameterization else ""
print("Model Version: Stable Diffusion V2.x 768v") if v2 and v_parameterization else ""
print(
    "Pretrained Model Path: ", pretrained_model_name_or_path
) if pretrained_model_name_or_path else print("No Pretrained Model path specified.")
print("VAE Path: ", vae) if vae else print("No VAE path specified.")
print("Output Path: ", output_dir)
# Out:
# Stored 'project_name' (str)
# Project Name:  idklora2
# Model Version: Stable Diffusion V1.x
# Pretrained Model Path:  /content/pretrained_model/realisticVisionV20_v20.safetensors
# No VAE path specified.
# Output Path:  /content/LoRA/output

# %%
# @title ## 5.2. Dataset Config
import os
import toml
import glob

dataset_repeats = 10  # @param {type:"number"}
# @markdown `activation_word` is not used in training if you train with captions/tags, but it is still printed to metadata.
activation_word = "idklora2"  # @param {type:"string"}
caption_extension = ".txt"  # @param ["none", ".txt", ".caption"]
# @markdown Please refer to `4.2.3. Custom Caption/Tag (Optional)` if you want to append `activation_word` to captions/tags
resolution = 512  # @param {type:"slider", min:512, max:1024, step:128}
flip_aug = False  # @param {type:"boolean"}
keep_tokens = 0  # @param {type:"number"}

def parse_folder_name(folder_name, default_num_repeats, default_class_token):
    folder_name_parts = folder_name.split("_")

    if len(folder_name_parts) == 2:
        if folder_name_parts[0].isdigit():
            num_repeats = int(folder_name_parts[0])
            class_token = folder_name_parts[1].replace("_", " ")
        else:
            num_repeats = default_num_repeats
            class_token = default_class_token
    else:
        num_repeats = default_num_repeats
        class_token = default_class_token

    return num_repeats, class_token

def find_image_files(path):
    supported_extensions = (".png", ".jpg", ".jpeg", ".webp", ".bmp")
    return [file for file in glob.glob(path + '/**/*', recursive=True) if file.lower().endswith(supported_extensions)]

def process_data_dir(data_dir, default_num_repeats, default_class_token, is_reg=False):
    subsets = []

    images = find_image_files(data_dir)
    if images:
        subsets.append({
            "image_dir": data_dir,
            "class_tokens": default_class_token,
            "num_repeats": default_num_repeats,
            **({"is_reg": is_reg} if is_reg else {}),
        })

    for root, dirs, files in os.walk(data_dir):
        for folder in dirs:
            folder_path = os.path.join(root, folder)
            images = find_image_files(folder_path)

            if images:
                num_repeats, class_token = parse_folder_name(folder, default_num_repeats, default_class_token)

                subset = {
                    "image_dir": folder_path,
                    "class_tokens": class_token,
                    "num_repeats": num_repeats,
                }

                if is_reg:
                    subset["is_reg"] = True

                subsets.append(subset)

    return subsets


train_subsets = process_data_dir(train_data_dir, dataset_repeats, activation_word)
reg_subsets = process_data_dir(reg_data_dir, dataset_repeats, activation_word, is_reg=True)

subsets = train_subsets + reg_subsets

config = {
    "general": {
        "enable_bucket": True,
        "caption_extension": caption_extension,
        "shuffle_caption": True,
        "keep_tokens": keep_tokens,
        "bucket_reso_steps": 64,
        "bucket_no_upscale": False,
    },
    "datasets": [
        {
            "resolution": resolution,
            "min_bucket_reso": 320 if resolution > 640 else 256,
            "max_bucket_reso": 1280 if resolution > 640 else 1024,
            "caption_dropout_rate": 0,
            "caption_tag_dropout_rate": 0,
            "caption_dropout_every_n_epochs": 0,
            "flip_aug": flip_aug,
            "color_aug": False,
            "face_crop_aug_range": None,
            "subsets": subsets,
        }
    ],
}

dataset_config = os.path.join(config_dir, "dataset_config.toml")

for key in config:
    if isinstance(config[key], dict):
        for sub_key in config[key]:
            if config[key][sub_key] == "":
                config[key][sub_key] = None
    elif config[key] == "":
        config[key] = None

config_str = toml.dumps(config)

with open(dataset_config, "w") as f:
    f.write(config_str)

print(config_str)
# Out:
# [[datasets]]
# resolution = 512
# min_bucket_reso = 256
# max_bucket_reso = 1024
# caption_dropout_rate = 0
# caption_tag_dropout_rate = 0
# caption_dropout_every_n_epochs = 0
# flip_aug = false
# color_aug = false
# [[datasets.subsets]]
# image_dir = "/content/LoRA/train_data"
# class_tokens = "idklora2"
# num_repeats = 10
#
#
# [general]
# enable_bucket = true
# caption_extension = ".txt"
# shuffle_caption = true
# keep_tokens = 0
# bucket_reso_steps = 64
# bucket_no_upscale = false

# %%
# @title ## 5.3. LoRA and Optimizer Config

# @markdown ### LoRA Config:
network_category = "LoRA"  # @param ["LoRA", "LoCon", "LoCon_Lycoris", "LoHa"]

# @markdown Recommended values:

# @markdown | network_category | network_dim | network_alpha | conv_dim | conv_alpha |
# @markdown | :---: | :---: | :---: | :---: | :---: |
# @markdown | LoRA | 32 | 1 | - | - |
# @markdown | LoCon | 16 | 8 | 8 | 1 |
# @markdown | LoHa | 8 | 4 | 4 | 1 |

# @markdown - Note that `dropout` and `cp_decomposition` are not available in this notebook.

# @markdown `conv_dim` and `conv_alpha` are needed to train `LoCon` and `LoHa`; skip them if you are training normal `LoRA`. However, when in doubt, set `dim = alpha`.
conv_dim = 32  # @param {'type':'number'}
conv_alpha = 16  # @param {'type':'number'}
# @markdown It's recommended not to set `network_dim` and `network_alpha` higher than 64, especially for `LoHa`.
# @markdown If you want to use a higher value for `dim` or `alpha`, consider using a higher learning rate, as models with higher dimensions tend to learn faster.
network_dim = 32  # @param {'type':'number'}
network_alpha = 16  # @param {'type':'number'}
# @markdown You can specify this field for resume training.
network_weight = ""  # @param {'type':'string'}
network_module = "lycoris.kohya" if network_category in ["LoHa", "LoCon_Lycoris"] else "networks.lora"
network_args = "" if network_category == "LoRA" else [
    f"conv_dim={conv_dim}", f"conv_alpha={conv_alpha}",
    ]
# @markdown ### <br>Optimizer Config:
# @markdown `NEW` Gamma for reducing the weight of high-loss timesteps. Lower numbers have a stronger effect. The paper recommends 5. Read the paper [here](https://arxiv.org/abs/2303.09556).
min_snr_gamma = -1 #@param {type:"number"}
# @markdown `AdamW8bit` was the old `--use_8bit_adam`.
optimizer_type = "AdamW8bit"  # @param ["AdamW", "AdamW8bit", "Lion", "SGDNesterov", "SGDNesterov8bit", "DAdaptation", "AdaFactor"]
# @markdown Additional arguments for optimizer, e.g: `["decouple=True","weight_decay=0.6"]`
optimizer_args = ""  # @param {'type':'string'}
# @markdown Set `unet_lr` to `1.0` if you use `DAdaptation` optimizer, because it's a [free learning rate](https://github.com/facebookresearch/dadaptation) algorithm.
# @markdown However, it is recommended to set `text_encoder_lr = 0.5 * unet_lr`.
# @markdown Also, you don't need to specify `learning_rate` value if both `unet_lr` and `text_encoder_lr` are defined.
train_unet = True  # @param {'type':'boolean'}
unet_lr = 1e-4  # @param {'type':'number'}
train_text_encoder = True  # @param {'type':'boolean'}
text_encoder_lr = 5e-5  # @param {'type':'number'}
lr_scheduler = "linear"  # @param ["linear", "cosine", "cosine_with_restarts", "polynomial", "constant", "constant_with_warmup", "adafactor"] {allow-input: false}
lr_warmup_steps = 0  # @param {'type':'number'}
# @markdown You can define `num_cycles` value for `cosine_with_restarts` or `power` value for `polynomial` in the field below.
lr_scheduler_num_cycles = 0  # @param {'type':'number'}
lr_scheduler_power = 0  # @param {'type':'number'}

if network_category == "LoHa":
  network_args.append("algo=loha")
elif network_category == "LoCon_Lycoris":
  network_args.append("algo=lora")

print("- LoRA Config:")
print(f"  - Min-SNR Weighting: {min_snr_gamma}") if not min_snr_gamma == -1 else ""
print(f"  - Loading network module: {network_module}")
if not network_category == "LoRA":
  print(f"  - network args: {network_args}")
print(f"  - {network_module} linear_dim set to: {network_dim}")
print(f"  - {network_module} linear_alpha set to: {network_alpha}")
if not network_category == "LoRA":
  print(f"  - {network_module} conv_dim set to: {conv_dim}")
  print(f"  - {network_module} conv_alpha set to: {conv_alpha}")

if not network_weight:
    print("  - No LoRA weight loaded.")
else:
    if os.path.exists(network_weight):
        print(f"  - Loading LoRA weight: {network_weight}")
    else:
        print(f"  - {network_weight} does not exist.")
        network_weight = ""

print("- Optimizer Config:")
print(f"  - Additional network category: {network_category}")
print(f"  - Using {optimizer_type} as Optimizer")
if optimizer_args:
    print(f"  - Optimizer Args: {optimizer_args}")
if train_unet and train_text_encoder:
    print("  - Train UNet and Text Encoder")
    print(f"    - UNet learning rate: {unet_lr}")
    print(f"    - Text encoder learning rate: {text_encoder_lr}")
if train_unet and not train_text_encoder:
    print("  - Train UNet only")
    print(f"    - UNet learning rate: {unet_lr}")
if train_text_encoder and not train_unet:
    print("  - Train Text Encoder only")
    print(f"    - Text encoder learning rate: {text_encoder_lr}")
print(f"  - Learning rate warmup steps: {lr_warmup_steps}")
print(f"  - Learning rate Scheduler: {lr_scheduler}")
if lr_scheduler == "cosine_with_restarts":
    print(f"  - lr_scheduler_num_cycles: {lr_scheduler_num_cycles}")
elif lr_scheduler == "polynomial":
    print(f"  - lr_scheduler_power: {lr_scheduler_power}")
# Out:
# - LoRA Config:
#   - Loading network module: networks.lora
#   - networks.lora linear_dim set to: 32
#   - networks.lora linear_alpha set to: 16
#   - No LoRA weight loaded.
# - Optimizer Config:
#   - Additional network category: LoRA
#   - Using AdamW8bit as Optimizer
#   - Train UNet and Text Encoder
#     - UNet learning rate: 0.0001
#     - Text encoder learning rate: 5e-05
#   - Learning rate warmup steps: 0
#   - Learning rate Scheduler: linear

# %%
# @title ## 5.4. Training Config

import toml
import os

# %store -r
lowram = False  # @param {type:"boolean"}
enable_sample_prompt = False  # @param {type:"boolean"}
sampler = "ddim"  # @param ["ddim", "pndm", "lms", "euler", "euler_a", "heun", "dpm_2", "dpm_2_a", "dpmsolver","dpmsolver++", "dpmsingle", "k_lms", "k_euler", "k_euler_a", "k_dpm_2", "k_dpm_2_a"]
noise_offset = 0.0  # @param {type:"number"}
num_epochs = 10  # @param {type:"number"}
vae_batch_size = 4  # @param {type:"number"}
train_batch_size = 6  # @param {type:"number"}
mixed_precision = "fp16"  # @param ["no","fp16","bf16"] {allow-input: false}
save_precision = "fp16"  # @param ["float", "fp16", "bf16"] {allow-input: false}
save_n_epochs_type = "save_every_n_epochs"  # @param ["save_every_n_epochs", "save_n_epoch_ratio"] {allow-input: false}
save_n_epochs_type_value = 1  # @param {type:"number"}
save_model_as = "safetensors"  # @param ["ckpt", "pt", "safetensors"] {allow-input: false}
max_token_length = 225  # @param {type:"number"}
clip_skip = 2  # @param {type:"number"}
gradient_checkpointing = False  # @param {type:"boolean"}
gradient_accumulation_steps = 1  # @param {type:"number"}
seed = -1  # @param {type:"number"}
logging_dir = "/content/LoRA/logs"
prior_loss_weight = 1.0

os.chdir(repo_dir)

sample_str = f"""
  masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt \
  --n lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry \
  --w 512 \
  --h 768 \
  --l 7 \
  --s 28
"""

config = {
    "model_arguments": {
        "v2": v2,
        "v_parameterization": v_parameterization if v2 and v_parameterization else False,
        "pretrained_model_name_or_path": pretrained_model_name_or_path,
        "vae": vae,
    },
    "additional_network_arguments": {
        "no_metadata": False,
        "unet_lr": float(unet_lr) if train_unet else None,
        "text_encoder_lr": float(text_encoder_lr) if train_text_encoder else None,
        "network_weights": network_weight,
        "network_module": network_module,
        "network_dim": network_dim,
        "network_alpha": network_alpha,
        "network_args": network_args,
        "network_train_unet_only": True if train_unet and not train_text_encoder else False,
        "network_train_text_encoder_only": True if train_text_encoder and not train_unet else False,
        "training_comment": None,
    },
    "optimizer_arguments": {
        "min_snr_gamma": min_snr_gamma if not min_snr_gamma == -1 else None,
        "optimizer_type": optimizer_type,
        "learning_rate": unet_lr,
        "max_grad_norm": 1.0,
        "optimizer_args": eval(optimizer_args) if optimizer_args else None,
        "lr_scheduler": lr_scheduler,
        "lr_warmup_steps": lr_warmup_steps,
        "lr_scheduler_num_cycles": lr_scheduler_num_cycles if lr_scheduler == "cosine_with_restarts" else None,
        "lr_scheduler_power": lr_scheduler_power if lr_scheduler == "polynomial" else None,
    },
    "dataset_arguments": {
        "cache_latents": True,
        "debug_dataset": False,
        "vae_batch_size": vae_batch_size,
    },
    "training_arguments": {
        "output_dir": output_dir,
        "output_name": project_name,
        "save_precision": save_precision,
        "save_every_n_epochs": save_n_epochs_type_value if save_n_epochs_type == "save_every_n_epochs" else None,
        "save_n_epoch_ratio": save_n_epochs_type_value if save_n_epochs_type == "save_n_epoch_ratio" else None,
        "save_last_n_epochs": None,
        "save_state": None,
        "save_last_n_epochs_state": None,
        "resume": None,
        "train_batch_size": train_batch_size,
        "max_token_length": 225,
        "mem_eff_attn": False,
        "xformers": True,
        "max_train_epochs": num_epochs,
        "max_data_loader_n_workers": 8,
        "persistent_data_loader_workers": True,
        "seed": seed if seed > 0 else None,
        "gradient_checkpointing": gradient_checkpointing,
        "gradient_accumulation_steps": gradient_accumulation_steps,
        "mixed_precision": mixed_precision,
        "clip_skip": clip_skip if not v2 else None,
        "logging_dir": logging_dir,
        "log_prefix": project_name,
        "noise_offset": noise_offset if noise_offset > 0 else None,
        "lowram": lowram,
    },
    "sample_prompt_arguments": {
        "sample_every_n_steps": None,
        "sample_every_n_epochs": 1 if enable_sample_prompt else 999999,
        "sample_sampler": sampler,
    },
    "dreambooth_arguments": {
        "prior_loss_weight": 1.0,
    },
    "saving_arguments": {
        "save_model_as": save_model_as
    },
}

config_path = os.path.join(config_dir, "config_file.toml")
prompt_path = os.path.join(config_dir, "sample_prompt.txt")

for key in config:
    if isinstance(config[key], dict):
        for sub_key in config[key]:
            if config[key][sub_key] == "":
                config[key][sub_key] = None
    elif config[key] == "":
        config[key] = None

config_str = toml.dumps(config)

def write_file(filename, contents):
    with open(filename, "w") as f:
        f.write(contents)

write_file(config_path, config_str)
write_file(prompt_path, sample_str)

print(config_str)
# Out:
# [model_arguments]
# v2 = false
# v_parameterization = false
# pretrained_model_name_or_path = "/content/pretrained_model/realisticVisionV20_v20.safetensors"
#
# [additional_network_arguments]
# no_metadata = false
# unet_lr = 0.0001
# text_encoder_lr = 5e-5
# network_module = "networks.lora"
# network_dim = 32
# network_alpha = 16
# network_train_unet_only = false
# network_train_text_encoder_only = false
#
# [optimizer_arguments]
# optimizer_type = "AdamW8bit"
# learning_rate = 0.0001
# max_grad_norm = 1.0
# lr_scheduler = "linear"
# lr_warmup_steps = 0
#
# [dataset_arguments]
# cache_latents = true
# debug_dataset = false
# vae_batch_size = 4
#
# [training_arguments]
# output_dir = "/content/LoRA/output"
# output_name = "idklora2"
# save_precision = "fp16"
# save_every_n_epochs = 1
# train_batch_size = 6
# max_token_length = 225
# mem_eff_attn = false
# xformers = true
# max_train_epochs = 10
# max_data_loader_n_workers = 8
# persistent_data_loader_workers = true
# gradient_checkpointing = false
# gradient_accumulation_steps = 1
# mixed_precision = "fp16"
# clip_skip = 2
# logging_dir = "/content/LoRA/logs"
# log_prefix = "idklora2"
# lowram = false
#
# [sample_prompt_arguments]
# sample_every_n_epochs = 999999
# sample_sampler = "ddim"
#
# [dreambooth_arguments]
# prior_loss_weight = 1.0
#
# [saving_arguments]
# save_model_as = "safetensors"

# %%
# !rm -rf  /content/LoRA/train_data

# %%
#@title ## 5.5. Start Training

#@markdown Check your config here if you want to edit something:
#@markdown - `sample_prompt` : /content/LoRA/config/sample_prompt.txt
#@markdown - `config_file` : /content/LoRA/config/config_file.toml
#@markdown - `dataset_config` : /content/LoRA/config/dataset_config.toml

#@markdown Generated sample can be seen here: /content/LoRA/output/sample

#@markdown You can import config from another session if you want.
sample_prompt = "/content/LoRA/config/sample_prompt.txt" #@param {type:'string'}
config_file = "/content/LoRA/config/config_file.toml" #@param {type:'string'}
dataset_config = "/content/LoRA/config/dataset_config.toml" #@param {type:'string'}

accelerate_conf = {
    "config_file" : accelerate_config,
    "num_cpu_threads_per_process" : 1,
}

train_conf = {
    "sample_prompts" : sample_prompt,
    "dataset_config" : dataset_config,
    "config_file" : config_file
}

def train(config):
    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    return args

accelerate_args = train(accelerate_conf)
train_args = train(train_conf)
final_args = f"accelerate launch {accelerate_args} train_network.py {train_args}"

os.chdir(repo_dir)
# !{final_args}
# Out:
# Loading settings from /content/LoRA/config/config_file.toml...
# /content/LoRA/config/config_file
# prepare tokenizer
# Downloading (…)olve/main/vocab.json: 961kB [00:00, 4.99MB/s]
# Downloading (…)olve/main/merges.txt: 525kB [00:00, 10.1MB/s]
# Downloading (…)cial_tokens_map.json: 100% 389/389 [00:00<00:00, 672kB/s]
# Downloading (…)okenizer_config.json: 100% 905/905 [00:00<00:00, 1.57MB/s]
# update token length: 225
# Load dataset config from /content/LoRA/config/dataset_config.toml
# prepare images.
# found directory /content/LoRA/train_data contains 302 image files
# 3020 train images with repeating.
# 0 reg images.
# no regularization images / 正則化画像が見つかりませんでした
# [Dataset 0]
#   batch_size: 6
#   resolution: (512, 512)
#   enable_bucket: True
#   min_bucket_reso: 256
#   max_bucket_reso: 1024
#   bucket_reso_steps: 64
#   bucket_no_upscale: False
#
#   [Subset 0 of Dataset 0]
#     image_dir: "/content/LoRA/train_data"
#     image_count: 302
#     num_repeats: 10
#     shuffle_caption: True
#     keep_tokens: 0
#     caption_dropout_rate: 0
#     caption_dropout_every_n_epoches: 0
#     caption_tag_dropout_rate: 0
#     color_aug: False
#     flip_aug: False
#     face_crop_aug_range: None
#     random_crop: False
#     token_warmup_min: 1,
#     token_warmup_step: 0,
#     is_reg: False
#     class_tokens: idklora2
#     caption_extension: .txt
#
#
# [Dataset 0]
# loading image sizes.
# 100% 302/302 [00:00<00:00, 13899.85it/s]
# make buckets
# number of images (including repeats) / 各bucketの画像枚数（繰り返し回数を含む）
# bucket 0: resolution (256, 832), count: 20
# bucket 1: resolution (256, 960), count: 10
# bucket 2: resolution (256, 1024), count: 10
# bucket 3: resolution (320, 704), count: 170
# bucket 4: resolution (320, 768), count: 60
# bucket 5: resolution (384, 640), count: 410
# bucket 6: resolution (448, 576), count: 660
# bucket 7: resolution (512, 512), count: 630
# bucket 8: resolution (576, 448), count: 490
# bucket 9: resolution (640, 384), count: 470
# bucket 10: resolution (704, 320), count: 70
# bucket 11: resolution (768, 320), count: 10
# bucket 12: resolution (832, 256), count: 10
# mean ar error (without repeats): 0.06653648757253222
# prepare accelerator
# Using accelerator 0.15.0 or above.
# loading model for process 0/1
# load StableDiffusion checkpoint
# loading u-net: <All keys matched successfully>
# loading vae: <All keys matched successfully>
# Downloading (…)lve/main/config.json: 4.52kB [00:00, 5.61MB/s]
# Downloading pytorch_model.bin: 100% 1.71G/1.71G [00:14<00:00, 118MB/s]
# loading text encoder: <All keys matched successfully>
# Replace CrossAttention.forward to use xformers
# [Dataset 0]
# caching latents.
# 100% 143/143 [00:32<00:00,  4.44it/s]
# import network module: networks.lora
# create LoRA network. base dim (rank): 32, alpha: 16
# create LoRA for Text Encoder: 72 modules.
# create LoRA for U-Net: 192 modules.
# enable LoRA for text encoder
# enable LoRA for U-Net
# prepare optimizer, data loader etc.
# CUDA SETUP: CUDA runtime path found: /usr/local/cuda-11.8/targets/x86_64-linux/lib/libcudart.so
# CUDA SETUP: Highest compute capability among GPUs detected: 7.5
# CUDA SETUP: Detected CUDA version 118
# CUDA SETUP: Loading binary /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so...
# use 8-bit AdamW optimizer | {}
# override steps. steps for 10 epochs is / 指定エポックまでのステップ数: 5080
# running training / 学習開始
#   num train images * repeats / 学習画像の数×繰り返し回数: 3020
#   num reg images / 正則化画像の数: 0
#   num batches per epoch / 1epochのバッチ数: 508
#   num epochs / epoch数: 10
#   batch size per device / バッチサイズ: 6
#   gradient accumulation steps / 勾配を合計するステップ数 = 1
#   total optimization steps / 学習ステップ数: 5080
# steps:   0% 0/5080 [00:00<?, ?it/s]epoch 1/10
# steps:  10% 508/5080 [11:50<1:46:34,  1.40s/it, loss=0.146]saving checkpoint: /content/LoRA/output/idklora2-000001.safetensors
# epoch 2/10
# steps:  20% 1016/5080 [23:41<1:34:44,  1.40s/it, loss=0.146]saving checkpoint: /content/LoRA/output/idklora2-000002.safetensors
# epoch 3/10
# steps:  30% 1524/5080 [35:31<1:22:52,  1.40s/it, loss=0.147]saving checkpoint: /content/LoRA/output/idklora2-000003.safetensors
# epoch 4/10
# steps:  40% 2032/5080 [47:21<1:11:01,  1.40s/it, loss=0.144]saving checkpoint: /content/LoRA/output/idklora2-000004.safetensors
# epoch 5/10
# steps:  50% 2540/5080 [59:12<59:12,  1.40s/it, loss=0.146]saving checkpoint: /content/LoRA/output/idklora2-000005.safetensors
# epoch 6/10
# steps:  60% 3048/5080 [1:11:03<47:22,  1.40s/it, loss=0.144]saving checkpoint: /content/LoRA/output/idklora2-000006.safetensors
# epoch 7/10
# steps:  70% 3556/5080 [1:22:54<35:32,  1.40s/it, loss=0.14]saving checkpoint: /content/LoRA/output/idklora2-000007.safetensors
# epoch 8/10
# steps:  80% 4064/5080 [1:34:45<23:41,  1.40s/it, loss=0.14]saving checkpoint: /content/LoRA/output/idklora2-000008.safetensors
# epoch 9/10
# steps:  81% 4135/5080 [1:36:26<22:02,  1.40s/it, loss=0.141]

# %% [markdown]
# # VI. Testing

# %%
# @title ## 6.1. Visualize loss graph (Optional)
training_logs_path = "/content/LoRA/logs"  # @param {type : "string"}

os.chdir(repo_dir)
# %load_ext tensorboard
# %tensorboard --logdir {training_logs_path}

# %%
# @title ## 6.2. Interrogating LoRA Weights
# @markdown Now you can check if your LoRA trained properly.
import os
import torch
import json
from safetensors.torch import load_file
from safetensors.torch import safe_open

# @markdown If you used `clip_skip = 2` during training, the values of `lora_te_text_model_encoder_layers_11_*` will be `0.0`, this is normal. These layers are not trained at this value of `Clip Skip`.
network_weight = ""  # @param {'type':'string'}
verbose = False  # @param {type:"boolean"}

def is_safetensors(path):
    return os.path.splitext(path)[1].lower() == ".safetensors"

def load_weight_data(file_path):
    if is_safetensors(file_path):
        return load_file(file_path)
    else:
        return torch.load(file_path, map_location="cuda")

def extract_lora_weights(weight_data):
    lora_weights = [
        (key, weight_data[key])
        for key in weight_data.keys()
        if "lora_up" in key or "lora_down" in key
    ]
    return lora_weights

def print_lora_weight_stats(lora_weights):
    print(f"Number of LoRA modules: {len(lora_weights)}")

    for key, value in lora_weights:
        value = value.to(torch.float32)
        print(f"{key}, {torch.mean(torch.abs(value))}, {torch.min(torch.abs(value))}")

def print_metadata(file_path):
    if is_safetensors(file_path):
        with safe_open(file_path, framework="pt") as f:
            metadata = f.metadata()
        if metadata is not None:
            print(f"\nLoad metadata for: {file_path}")
            print(json.dumps(metadata, indent=4))
    else:
        print("No metadata saved, your model is not in safetensors format")

def main(file_path, verbose: bool):
    weight_data = load_weight_data(file_path)

    if verbose:
        lora_weights = extract_lora_weights(weight_data)
        print_lora_weight_stats(lora_weights)

    print_metadata(file_path)

if __name__ == "__main__":
    main(network_weight, verbose)

# %%
# @title ## 6.3. Inference
# %store -r

# @markdown ### LoRA Config
# @markdown Currently, `LoHa` and `LoCon_Lycoris` are not supported. Please run `Portable Web UI` instead
network_weight = ""  # @param {'type':'string'}
network_mul = 0.7  # @param {type:"slider", min:-1, max:2, step:0.05}
network_module = "networks.lora"
network_args = ""

# @markdown ### <br> General Config
v2 = False  # @param {type:"boolean"}
v_parameterization = False  # @param {type:"boolean"}
prompt = "masterpiece, best quality, 1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt"  # @param {type: "string"}
negative = "lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry"  # @param {type: "string"}
model = "/content/pretrained_model/AnyLoRA.safetensors"  # @param {type: "string"}
vae = ""  # @param {type: "string"}
outdir = "/content/tmp"  # @param {type: "string"}
scale = 7  # @param {type: "slider", min: 1, max: 40}
sampler = "ddim"  # @param ["ddim", "pndm", "lms", "euler", "euler_a", "heun", "dpm_2", "dpm_2_a", "dpmsolver","dpmsolver++", "dpmsingle", "k_lms", "k_euler", "k_euler_a", "k_dpm_2", "k_dpm_2_a"]
steps = 28  # @param {type: "slider", min: 1, max: 100}
precision = "fp16"  # @param ["fp16", "bf16"] {allow-input: false}
width = 512  # @param {type: "integer"}
height = 768  # @param {type: "integer"}
images_per_prompt = 4  # @param {type: "integer"}
batch_size = 4  # @param {type: "integer"}
clip_skip = 2  # @param {type: "slider", min: 1, max: 40}
seed = -1  # @param {type: "integer"}

final_prompt = f"{prompt} --n {negative}"

config = {
    "v2": v2,
    "v_parameterization": v_parameterization,
    "network_module": network_module,
    "network_weight": network_weight,
    "network_mul": float(network_mul),
    "network_args": eval(network_args) if network_args else None,
    "ckpt": model,
    "outdir": outdir,
    "xformers": True,
    "vae": vae if vae else None,
    "fp16": True,
    "W": width,
    "H": height,
    "seed": seed if seed > 0 else None,
    "scale": scale,
    "sampler": sampler,
    "steps": steps,
    "max_embeddings_multiples": 3,
    "batch_size": batch_size,
    "images_per_prompt": images_per_prompt,
    "clip_skip": clip_skip if not v2 else None,
    "prompt": final_prompt,
}

args = ""
for k, v in config.items():
    if k.startswith("_"):
        args += f'"{v}" '
    elif isinstance(v, str):
        args += f'--{k}="{v}" '
    elif isinstance(v, bool) and v:
        args += f"--{k} "
    elif isinstance(v, float) and not isinstance(v, bool):
        args += f"--{k}={v} "
    elif isinstance(v, int) and not isinstance(v, bool):
        args += f"--{k}={v} "

final_args = f"python gen_img_diffusers.py {args}"

os.chdir(repo_dir)
# !{final_args}

# %%
#@title ## 6.4. Launch Portable Web UI
import os
import random
import shutil
import zipfile
import time
import json
from google.colab import drive
from datetime import timedelta
from subprocess import getoutput
from IPython.display import clear_output, display, HTML
from IPython.utils import capture
from tqdm import tqdm

webui_dir = os.path.join(root_dir, "stable-diffusion-webui")
tmp_dir = os.path.join(root_dir, "tmp")
patches_dir = os.path.join(root_dir, "patches")
deps_dir = os.path.join(root_dir, "deps")
extensions_dir = os.path.join(webui_dir, "extensions")
control_dir = os.path.join(webui_dir, "models/ControlNet")

webui_models_dir = os.path.join(webui_dir, "models/Stable-diffusion")
webui_lora_dir = os.path.join(webui_dir, "models/Lora")
webui_vaes_dir = os.path.join(webui_dir, "models/VAE")

control_net_max_models_num = 2
theme = "ogxBGreen"

default_prompt = "masterpiece, best quality,"
default_neg_prompt = "(worst quality, low quality:1.4)"
default_sampler = "DPM++ 2M Karras"
default_steps = 20
default_width = 512
default_height = 768
default_denoising_strength = 0.55
default_cfg_scale = 7

config_file = os.path.join(webui_dir, "config.json")
ui_config_file = os.path.join(webui_dir, "ui-config.json")
webui_style_path = os.path.join(webui_dir, "style.css")

os.chdir(root_dir)

for dir in [patches_dir, deps_dir]:
    os.makedirs(dir, exist_ok=True)

package_url = [
    f"https://huggingface.co/Linaqruf/fast-repo/resolve/main/anapnoe-webui.tar.lz4",
    f"https://huggingface.co/Linaqruf/fast-repo/resolve/main/anapnoe-webui-deps.tar.lz4",
    f"https://huggingface.co/Linaqruf/fast-repo/resolve/main/anapnoe-webui-cache.tar.lz4",
]

def pre_download(desc):
    for package in tqdm(package_url, desc=desc):
        with capture.capture_output() as cap:
            package_name = os.path.basename(package)
            # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d {root_dir} -o {package_name} {package}
            if package_name == f"anapnoe-webui-deps.tar.lz4":
                # !tar -xI lz4 -f {package_name} --overwrite-dir --directory=/usr/local/lib/python3.10/dist-packages/
            else:
                # !tar -xI lz4 -f {package_name} --directory=/
            os.remove(package_name)
            del cap

    if os.path.exists("/usr/local/lib/python3.10/dist-packages/ffmpy-0.3.0.dist-info"):
        shutil.rmtree("/usr/local/lib/python3.10/dist-packages/ffmpy-0.3.0.dist-info")

    s = getoutput("nvidia-smi")
    with capture.capture_output() as cap:
        if not "T4" in s:
            # !pip uninstall -y xformers
            # !pip install -q xformers==0.0.18 triton
        del cap


def read_config(filename):
    if filename.endswith(".json"):
        with open(filename, "r") as f:
          config = json.load(f)
    else:
        with open(filename, 'r') as f:
          config = f.read()
    return config


def write_config(filename, config):
    if filename.endswith(".json"):
        with open(filename, "w") as f:
            json.dump(config, f, indent=4)
    else:
        with open(filename, 'w', encoding="utf-8") as f:
            f.write(config)


def open_theme(filename):
    themes_folder = os.path.join(webui_dir, "extensions-builtin/sd_theme_editor/themes")
    themes_file = os.path.join(themes_folder, f"{filename}.css")
    webui_style_path = os.path.join(webui_dir, "style.css")

    style_config = read_config(webui_style_path)
    style_css_contents = style_config.split("/*BREAKPOINT_CSS_CONTENT*/")[1]

    theme_config = read_config(themes_file)
    style_data = ":host{" + theme_config + "}" + "/*BREAKPOINT_CSS_CONTENT*/" + style_css_contents
    write_config(webui_style_path, style_data)


def change_config(filename):
    config = read_config(filename)
    if not "stable-diffusion-webui" in config["disabled_extensions"]:
        config["disabled_extensions"].append("stable-diffusion-webui")
    config["outdir_txt2img_samples"] = os.path.join(tmp_dir, "outputs/txt2img-images")
    config["outdir_img2img_samples"] = os.path.join(tmp_dir, "outputs/img2img-images")
    config["outdir_extras_samples"] = os.path.join(tmp_dir, "outputs/extras-images")
    config["outdir_txt2img_grids"] = os.path.join(tmp_dir, "outputs/txt2img-grids")
    config["outdir_img2img_grids"] = os.path.join(tmp_dir, "outputs/img2img-grids")
    config["outdir_save"] = os.path.join(tmp_dir, "log/images")
    config["control_net_max_models_num"] = control_net_max_models_num
    config["control_net_models_path"] = control_dir
    config["control_net_allow_script_control"] = True
    config["additional_networks_extra_lora_path"] = webui_lora_dir
    config["CLIP_stop_at_last_layers"] = 2
    config["eta_noise_seed_delta"] = 0
    config["show_progress_every_n_steps"] = 10
    config["show_progressbar"] = True
    config["quicksettings"] = "sd_model_checkpoint, sd_vae, CLIP_stop_at_last_layers, use_old_karras_scheduler_sigmas, always_discard_next_to_last_sigma"
    write_config(filename, config)


def change_ui_config(filename):
    config = read_config(filename)
    config["txt2img/Prompt/value"] = default_prompt
    config["txt2img/Negative prompt/value"] = default_neg_prompt
    config["txt2img/Sampling method/value"] = default_sampler
    config["txt2img/Sampling steps/value"] = default_steps
    config["txt2img/Width/value"] = default_width
    config["txt2img/Height/value"] = default_height
    config["txt2img/Upscaler/value"] = "Latent (nearest-exact)"
    config["txt2img/Denoising strength/value"] = default_denoising_strength
    config["txt2img/CFG Scale/value"] = default_cfg_scale
    config["img2img/Prompt/value"] = default_prompt
    config["img2img/Negative prompt/value"] = default_neg_prompt
    config["img2img/Sampling method/value"] = default_sampler
    config["img2img/Sampling steps/value"] = default_steps
    config["img2img/Width/value"] = default_width
    config["img2img/Height/value"] = default_height
    config["img2img/Denoising strength/value"] = default_denoising_strength
    config["img2img/CFG Scale/value"] = default_cfg_scale
    write_config(filename, config)


def update_extensions():
    start_time = time.time()
    extensions_updated = []
    with tqdm(
        total=len(os.listdir(extensions_dir)),
        desc="[1;32mUpdating extensions",
        mininterval=0,
    ) as pbar:
        for dir in os.listdir(extensions_dir):
            if os.path.isdir(os.path.join(extensions_dir, dir)):
                os.chdir(os.path.join(extensions_dir, dir))
                try:
                    with capture.capture_output() as cap:
                        # !git fetch origin
                        # !git pull
                except Exception as e:
                    print(f"[1;32mAn error occurred while updating {dir}: {e}")

                output = cap.stdout.strip()
                if "Already up to date." not in output:
                    extensions_updated.append(dir)
                pbar.update(1)

    print("\n")
    for ext in extensions_updated:
        print(f"[1;32m- {ext} updated to new version")

    end_time = time.time()
    elapsed_time = int(end_time - start_time)

    if elapsed_time < 60:
        print(f"\n[1;32mAll extensions are up to date. Took {elapsed_time} sec")
    else:
        mins, secs = divmod(elapsed_time, 60)
        print(f"\n[1;32mAll extensions are up to date. Took {mins} mins {secs} sec")


def main():
    start_time = time.time()

    print("[1;32mInstalling...\n")

    if not os.path.exists(webui_dir):
        desc = "[1;32mUnpacking Webui"
        pre_download(desc)
    else:
        print("[1;32mAlready installed, skipping...")

    with capture.capture_output() as cap:
        os.chdir(os.path.join(webui_dir, "repositories/stable-diffusion-stability-ai"))
        # !git apply {patches_dir}/stablediffusion-lowram.patch

        # !sed -i "s@os.path.splitext(checkpoint_.*@os.path.splitext(checkpoint_file); map_location='cuda'@" {webui_dir}/modules/sd_models.py
        # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' {webui_dir}/webui.py

        # !sed -i "s@'cpu'@'cuda'@" {webui_dir}/modules/extras.py
        del cap

    end_time = time.time()
    elapsed_time = int(end_time - start_time)

    change_config(config_file)
    change_ui_config(ui_config_file)
    open_theme(theme)

    if elapsed_time < 60:
        print(f"[1;32mFinished unpacking. Took {elapsed_time} sec")
    else:
        mins, secs = divmod(elapsed_time, 60)
        print(f"[1;32mFinished unpacking. Took {mins} mins {secs} sec")

    update_extensions()

    #@markdown > Get <b>your</b> `ngrok_token` [here](https://dashboard.ngrok.com/get-started/your-authtoken)
    ngrok_token = "" #@param {type: 'string'}
    ngrok_region = "ap" #@param ["us", "eu", "au", "ap", "sa", "jp", "in"]

    with capture.capture_output() as cap:
      for file in os.listdir(output_dir):
        file_path = os.path.join(output_dir, file)
        if file_path.endswith((".safetensors", ".pt", ".ckpt")):
          # !ln "{file_path}" {webui_lora_dir}

      for file in os.listdir(pretrained_model):
        file_path = os.path.join(pretrained_model, file)
        if file_path.endswith((".safetensors", ".ckpt")):
          # !ln "{file_path}" {webui_models_dir}

      for file in os.listdir(vae_dir):
        file_path = os.path.join(vae_dir, file)
        if file_path.endswith(".vae.pt"):
          # !ln "{file_path}" {webui_vaes_dir}

      del cap

    os.chdir(webui_dir)

    print("[1;32m")

    config = {
        "enable-insecure-extension-access": True,
        "disable-safe-unpickle": True,
        "multiple": True if not ngrok_token else False,
        "ckpt-dir": webui_models_dir,
        "vae-dir": webui_vaes_dir,
        "share": True if not ngrok_token else False,
        "no-half-vae": True,
        "lowram": True,
        "gradio-queue": True,
        "no-hashing": True,
        "disable-console-progressbars": True,
        "ngrok": ngrok_token if ngrok_token else None,
        "ngrok-region": ngrok_region if ngrok_token else None,
        "xformers": True,
        "opt-sub-quad-attention": True,
        "opt-channelslast": True,
        "theme": "dark"
    }

    args = ""
    for k, v in config.items():
        if k.startswith("_"):
            args += f'"{v}" '
        elif isinstance(v, str):
            args += f'--{k}="{v}" '
        elif isinstance(v, bool) and v:
            args += f"--{k} "
        elif isinstance(v, float) and not isinstance(v, bool):
            args += f"--{k}={v} "
        elif isinstance(v, int) and not isinstance(v, bool):
            args += f"--{k}={v} "

    final_args = f"python launch.py {args}"

    os.chdir(webui_dir)
    # !{final_args}

main()

# %% [markdown]
# # VII. Deployment

# %%
# @title ## 7.1. Upload Config
from huggingface_hub import login
from huggingface_hub import HfApi
from huggingface_hub.utils import validate_repo_id, HfHubHTTPError

# @markdown Login to Huggingface Hub
# @markdown > Get **your** huggingface `WRITE` token [here](https://huggingface.co/settings/tokens)
write_token = ""  # @param {type:"string"}
# @markdown Fill this if you want to upload to your organization, or just leave it empty.
orgs_name = ""  # @param{type:"string"}
# @markdown If your model/dataset repo does not exist, it will automatically create it.
model_name = "your-model-name"  # @param{type:"string"}
dataset_name = "your-dataset-name"  # @param{type:"string"}
make_private = False  # @param{type:"boolean"}

def authenticate(write_token):
    login(write_token, add_to_git_credential=True)
    api = HfApi()
    return api.whoami(write_token), api


def create_repo(api, user, orgs_name, repo_name, repo_type, make_private=False):
    global model_repo
    global datasets_repo

    if orgs_name == "":
        repo_id = user["name"] + "/" + repo_name.strip()
    else:
        repo_id = orgs_name + "/" + repo_name.strip()

    try:
        validate_repo_id(repo_id)
        api.create_repo(repo_id=repo_id, repo_type=repo_type, private=make_private)
        print(f"{repo_type.capitalize()} repo '{repo_id}' didn't exist, creating repo")
    except HfHubHTTPError as e:
        print(f"{repo_type.capitalize()} repo '{repo_id}' exists, skipping create repo")

    if repo_type == "model":
        model_repo = repo_id
        print(f"{repo_type.capitalize()} repo '{repo_id}' link: https://huggingface.co/{repo_id}\n")
    else:
        datasets_repo = repo_id
        print(f"{repo_type.capitalize()} repo '{repo_id}' link: https://huggingface.co/datasets/{repo_id}\n")

user, api = authenticate(write_token)

if model_name:
    create_repo(api, user, orgs_name, model_name, "model", make_private)
if dataset_name:
    create_repo(api, user, orgs_name, dataset_name, "dataset", make_private)

# %% [markdown]
# ## 7.2. Upload with Huggingface Hub

# %%
# @title ### 7.2.1. Upload LoRA
from huggingface_hub import HfApi
from pathlib import Path

# %store -r

api = HfApi()

# @markdown This will be uploaded to model repo
model_path = "/content/LoRA/output"  # @param {type :"string"}
path_in_repo = ""  # @param {type :"string"}

# @markdown Now you can save your config file for future use
config_path = "/content/LoRA/config"  # @param {type :"string"}

# @markdown Other Information
commit_message = ""  # @param {type :"string"}

if not commit_message:
    commit_message = f"feat: upload {project_name} lora model"

def upload_to_hf(model_path, is_folder, is_config):
    path_obj = Path(model_path)
    trained_model = path_obj.parts[-1]

    if path_in_repo:
        trained_model = path_in_repo

    if is_config:
        trained_model = f"{project_name}_config"

    print(f"Uploading {trained_model} to https://huggingface.co/{model_repo}")
    print("Please wait...")

    if is_folder:
        api.upload_folder(
            folder_path=model_path,
            path_in_repo=trained_model,
            repo_id=model_repo,
            commit_message=commit_message,
            ignore_patterns=".ipynb_checkpoints",
        )
        print(f"Upload success, located at https://huggingface.co/{model_repo}/tree/main\n")
    else:
        api.upload_file(
            path_or_fileobj=model_path,
            path_in_repo=trained_model,
            repo_id=model_repo,
            commit_message=commit_message,
        )
        print(f"Upload success, located at https://huggingface.co/{model_repo}/blob/main/{trained_model}\n")

def upload():
    is_model_file = model_path.endswith((".ckpt", ".safetensors", ".pt"))
    upload_to_hf(model_path, not is_model_file, False)

    if config_path:
        upload_to_hf(config_path, True, True)

upload()

# %%
# @title ### 7.2.2. Upload Dataset
from huggingface_hub import HfApi
from pathlib import Path
import shutil
import zipfile
import os

api = HfApi()

# @markdown This will be compressed to zip and  uploaded to datasets repo, leave it empty if not necessary
train_data_path = "/content/LoRA/train_data"  # @param {type :"string"}

# @markdown `Nerd stuff, only if you want to save training logs`
logs_path = "/content/LoRA/logs"  # @param {type :"string"}

tmp_dataset = f"/content/LoRA/{project_name}_dataset" if project_name else "/content/LoRA/tmp_dataset"
tmp_train_data = f"{tmp_dataset}/train_data"
dataset_zip = f"{tmp_dataset}.zip"

# @markdown Other Information
commit_message = ""  # @param {type :"string"}

if not commit_message:
    commit_message = f"feat: upload {project_name} dataset and logs"

os.makedirs(tmp_dataset, exist_ok=True)
os.makedirs(tmp_train_data, exist_ok=True)

def upload_dataset(dataset_path, is_zip):
    path_obj = Path(dataset_path)
    dataset_name = path_obj.parts[-1]

    print(f"Uploading {dataset_name} to https://huggingface.co/datasets/{datasets_repo}")
    print("Please wait...")

    if is_zip:
        api.upload_file(
            path_or_fileobj=dataset_path,
            path_in_repo=dataset_name,
            repo_id=datasets_repo,
            repo_type="dataset",
            commit_message=commit_message,
        )
        print(f"Upload success, located at https://huggingface.co/datasets/{datasets_repo}/blob/main/{dataset_name}\n")
    else:
        api.upload_folder(
            folder_path=dataset_path,
            path_in_repo=dataset_name,
            repo_id=datasets_repo,
            repo_type="dataset",
            commit_message=commit_message,
            ignore_patterns=".ipynb_checkpoints",
        )
        print(f"Upload success, located at https://huggingface.co/datasets/{datasets_repo}/tree/main/{dataset_name}\n")

def zip_file(folder_path):
    zip_path = f"{folder_path}.zip"
    with zipfile.ZipFile(zip_path, "w") as zip_file:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                zip_file.write(os.path.join(root, file))

def move(src_path, dst_path, move_metadata):
    metadata_files = [
        "meta_cap.json",
        "meta_cap_dd.json",
        "meta_lat.json",
        "meta_clean.json",
        "meta_final.json",
    ]

    if os.path.exists(src_path):
        shutil.move(src_path, dst_path)

    if move_metadata:
        parent_meta_path = os.path.dirname(src_path)

        for filename in os.listdir(parent_meta_path):
            file_path = os.path.join(parent_meta_path, filename)
            if filename in metadata_files:
                shutil.move(file_path, dst_path)

def upload():
    if train_data_path:
        move(train_data_path, tmp_train_data, False)
        zip_file(tmp_dataset)
        upload_dataset(dataset_zip, True)
        os.remove(dataset_zip)
    if logs_path:
        upload_dataset(logs_path, False)

upload()

# %% [markdown]
# ## 7.3. Upload with GIT (Alternative)

# %%
# @title ### 7.3.1. Clone Repository

clone_model = True  # @param {'type': 'boolean'}
clone_dataset = True  # @param {'type': 'boolean'}

def clone_repository(repo_url, local_path):
    # !git lfs install --skip-smudge
    os.environ["GIT_LFS_SKIP_SMUDGE"] = "1"
    # !git clone {repo_url} {local_path}

if clone_model:
    clone_repository(f"https://huggingface.co/{model_repo}", f"/content/{model_name}")

if clone_dataset:
    clone_repository(f"https://huggingface.co/datasets/{datasets_repo}", f"/content/{dataset_name}")

# %%
# @title ### 7.3.2. Commit using Git
import os

os.chdir(root_dir)

# @markdown Choose which repo you want to commit
commit_model = True  # @param {'type': 'boolean'}
commit_dataset = True  # @param {'type': 'boolean'}
# @markdown Other Information
commit_message = ""  # @param {type :"string"}

if not commit_message:
    commit_message = f"feat: upload {project_name} lora model and dataset"

# !git config --global user.email "example@mail.com"
# !git config --global user.name "example"

def commit(repo_folder, commit_message):
    os.chdir(os.path.join(root_dir, repo_folder))
    # !git lfs install
    # !huggingface-cli lfs-enable-largefiles .
    # !git add .
    # !git commit -m "{commit_message}"
    # !git push


if commit_model:
    commit(model_name, commit_message)

if commit_dataset:
    commit(dataset_name, commit_message)
